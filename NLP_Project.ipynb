# %% [markdown]
# ## Project

# %%
# importing libraries and dataset
import pandas as pd

# Tab seperated data set
messages = pd.read_csv('/content/SMSSpamCollection.txt', sep='\t', names=["label","message"])

# %%
print(messages.shape)
messages.head()
# Out:
# (5572, 2)
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Data cleaning and Preprocessing
import re
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# Stemming
ps = PorterStemmer()

# %%
messages['message'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
# data cleaning and stemming
corpus = []

for i in range(len(messages)):
  review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus[:5]
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri question std txt rate c appli',
#  'u dun say earli hor u c alreadi say',
#  'nah think goe usf live around though']

# %% [markdown]
# # Create Bag Of Words

# %%
## Create the Bag OF Words model
from sklearn.feature_extraction.text import CountVectorizer

## for Binary BOW enable binary=True
cv = CountVectorizer(max_features = 2500, binary = True, ngram_range = (1,2))

## independent features
X = cv.fit_transform(corpus).toarray()

# %%
print(X.shape)
X[1]
# Out:
# (5572, 2500)
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cv.vocabulary_
# Out:
# {'go': 802,
#  'point': 1615,
#  'crazi': 451,
#  'avail': 122,
#  'bugi': 229,
#  'great': 860,
#  'world': 2428,
#  'la': 1083,
#  'cine': 339,
#  'got': 848,
#  'wat': 2336,
#  'ok': 1478,
#  'lar': 1093,
#  'joke': 1054,
#  'wif': 2393,
#  'free': 716,
#  'entri': 614,
#  'wkli': 2417,
#  'comp': 395,
#  'win': 2398,
#  'cup': 466,
#  'final': 678,
#  'st': 1975,
#  'may': 1265,
#  'text': 2077,
#  'receiv': 1701,
#  'question': 1669,
#  'std': 1988,
#  'txt': 2196,
#  'rate': 1681,
#  'appli': 86,
#  'free entri': 723,
#  'entri wkli': 616,
#  'std txt': 1989,
#  'txt rate': 2204,
#  'rate appli': 1682,
#  'dun': 579,
#  'say': 1798,
#  'earli': 585,
#  'alreadi': 55,
#  'nah': 1389,
#  'think': 2096,
#  'goe': 823,
#  'usf': 2271,
#  'live': 1162,
#  'around': 98,
#  'though': 2107,
#  'freemsg': 736,
#  'hey': 918,
#  'darl': 486,
#  'week': 2362,
#  'word': 2423,
#  'back': 139,
#  'like': 1148,
#  'fun': 753,
#  'still': 1990,
#  'tb': 2057,
#  'xxx': 2464,
#  'send': 1827,
#  'even': 623,
#  'brother': 219,
#  'speak': 1958,
#  'treat': 2174,
#  'per': 1546,
#  'request': 1737,
#  'set': 1849,
#  'callertun': 274,
#  'caller': 271,
#  'press': 1642,
#  'copi': 434,
#  'friend': 742,
#  'per request': 1552,
#  'set callertun': 1850,
#  'callertun caller': 275,
#  'caller press': 272,
#  'press copi': 1643,
#  'copi friend': 435,
#  'friend callertun': 743,
#  'winner': 2403,
#  'valu': 2278,
#  'network': 1408,
#  'custom': 471,
#  'select': 1821,
#  'prize': 1651,
#  'reward': 1751,
#  'claim': 342,
#  'call': 245,
#  'code': 362,
#  'valid': 2276,
#  'hour': 970,
#  'claim call': 343,
#  'call claim': 249,
#  'claim code': 344,
#  'mobil': 1322,
#  'month': 1342,
#  'entitl': 612,
#  'updat': 2236,
#  'latest': 1103,
#  'colour': 376,
#  'camera': 280,
#  'co': 359,
#  'entitl updat': 613,
#  'updat latest': 2238,
#  'latest colour': 1105,
#  'free call': 719,
#  'call mobil': 259,
#  'mobil updat': 1331,
#  'updat co': 2237,
#  'co free': 360,
#  'gonna': 828,
#  'home': 949,
#  'soon': 1941,
#  'want': 2324,
#  'talk': 2053,
#  'stuff': 2015,
#  'anymor': 73,
#  'tonight': 2156,
#  'cri': 455,
#  'enough': 609,
#  'today': 2137,
#  'want talk': 2332,
#  'six': 1899,
#  'chanc': 313,
#  'cash': 298,
#  'pound': 1628,
#  'cost': 437,
#  'day': 493,
#  'repli': 1728,
#  'hl': 933,
#  'info': 1018,
#  'chanc win': 315,
#  'win cash': 2399,
#  'repli hl': 1730,
#  'hl info': 934,
#  'urgent': 2260,
#  'membership': 1278,
#  'www': 2446,
#  'net': 1406,
#  'pobox': 1610,
#  'ldnw': 1116,
#  'week free': 2364,
#  'txt word': 2206,
#  'search': 1807,
#  'right': 1753,
#  'thank': 2086,
#  'promis': 1661,
#  'wont': 2422,
#  'take': 2050,
#  'help': 916,
#  'wonder': 2421,
#  'bless': 184,
#  'time': 2120,
#  'date': 491,
#  'sunday': 2030,
#  'use': 2269,
#  'credit': 453,
#  'click': 355,
#  'wap': 2333,
#  'link': 1157,
#  'next': 1421,
#  'messag': 1284,
#  'http': 979,
#  'com': 379,
#  'oh': 1474,
#  'watch': 2341,
#  'eh': 596,
#  'rememb': 1721,
#  'spell': 1968,
#  'name': 1391,
#  'ye': 2475,
#  'naughti': 1398,
#  'make': 1232,
#  'wet': 2382,
#  'fine': 684,
#  'way': 2346,
#  'feel': 667,
#  'england': 605,
#  'dont': 559,
#  'miss': 1309,
#  'team': 2062,
#  'news': 1420,
#  'ur': 2239,
#  'nation': 1395,
#  'eg': 594,
#  'tri': 2176,
#  'wq': 2440,
#  'dont miss': 561,
#  'serious': 1841,
#  'ha': 887,
#  'ha ha': 888,
#  'pay': 1541,
#  'first': 687,
#  'da': 476,
#  'stock': 1992,
#  'comin': 393,
#  'aft': 30,
#  'finish': 686,
#  'lunch': 1222,
#  'str': 2008,
#  'lor': 1188,
#  'ard': 92,
#  'smth': 1920,
#  'alright': 56,
#  'meet': 1272,
#  'sooner': 1942,
#  'forc': 704,
#  'eat': 590,
#  'realli': 1696,
#  'hungri': 984,
#  'tho': 2106,
#  'suck': 2023,
#  'mark': 1248,
#  'get': 775,
#  'worri': 2430,
#  'know': 1080,
#  'sick': 1877,
#  'turn': 2192,
#  'pizza': 1577,
#  'lol': 1175,
#  'alway': 59,
#  'convinc': 430,
#  'catch': 304,
#  'bu': 225,
#  'fri': 740,
#  'egg': 595,
#  'tea': 2060,
#  'mom': 1337,
#  'left': 1125,
#  'dinner': 542,
#  'love': 1197,
#  'amp': 62,
#  'pack': 1524,
#  'car': 291,
#  'let': 1135,
#  'room': 1763,
#  'let know': 1137,
#  'work': 2424,
#  'feel like': 669,
#  'wait': 2308,
#  'clear': 354,
#  'sure': 2039,
#  'us': 2268,
#  'yeah': 2480,
#  'child': 330,
#  'till': 2119,
#  'cheer': 326,
#  'yeah got': 2481,
#  'tell': 2067,
#  'anyth': 75,
#  'tell anyth': 2068,
#  'quick': 1670,
#  'subscript': 2021,
#  'rington': 1756,
#  'uk': 2218,
#  'charg': 318,
#  'pleas': 1593,
#  'confirm': 406,
#  'mobil charg': 1324,
#  'repli ye': 1732,
#  'yup': 2498,
#  'look': 1183,
#  'msg': 1365,
#  'learn': 1118,
#  'nd': 1399,
#  'lesson': 1134,
#  'go home': 810,
#  'oop': 1499,
#  'roommat': 1764,
#  'done': 558,
#  'see': 1815,
#  'letter': 1138,
#  'decid': 511,
#  'anyth lor': 77,
#  'hello': 915,
#  'saturday': 1792,
#  'tomo': 2145,
#  'invit': 1026,
#  'pl': 1578,
#  'ahead': 39,
#  'weekend': 2368,
#  'abiola': 1,
#  'great weekend': 862,
#  'forget': 706,
#  'need': 1403,
#  'crave': 450,
#  'sweet': 2044,
#  'want need': 2329,
#  'burn': 232,
#  'sm': 1912,
#  'nokia': 1434,
#  'camcord': 276,
#  'deliveri': 523,
#  'tomorrow': 2146,
#  'call repli': 264,
#  'free nokia': 729,
#  'nokia mobil': 1439,
#  'mobil free': 1328,
#  'free camcord': 720,
#  'pleas call': 1594,
#  'deliveri tomorrow': 524,
#  'hope': 955,
#  'man': 1236,
#  'well': 2375,
#  'lt': 1213,
#  'gt': 867,
#  'inch': 1013,
#  'lt gt': 1215,
#  'miss call': 1312,
#  'nigeria': 1426,
#  'tyler': 2213,
#  'could': 442,
#  'mayb': 1266,
#  'ask': 106,
#  'bit': 180,
#  'hospit': 965,
#  'kept': 1067,
#  'weak': 2355,
#  'want go': 2327,
#  'saw': 1797,
#  'class': 352,
#  'first time': 688,
#  'usual': 2272,
#  'run': 1775,
#  'half': 893,
#  'almost': 52,
#  'whole': 2390,
#  'second': 1810,
#  'like lt': 1151,
#  'fyi': 756,
#  'ride': 1752,
#  'morn': 1347,
#  'place': 1585,
#  'wow': 2438,
#  'never': 1412,
#  'realiz': 1695,
#  'thought': 2108,
#  'sinc': 1888,
#  'best': 166,
#  'seem': 1819,
#  'happi': 900,
#  'sorri': 1944,
#  'give': 794,
#  'offer': 1469,
#  'ac': 4,
#  'new': 1413,
#  'red': 1707,
#  'play': 1587,
#  'ice': 993,
#  'correct': 436,
#  'end': 601,
#  'sm ac': 1913,
#  'yesterday': 2489,
#  'find': 680,
#  'congrat': 408,
#  'year': 2483,
#  'special': 1961,
#  'cinema': 340,
#  'pass': 1536,
#  'etc': 619,
#  'bx': 236,
#  'ip': 1030,
#  'pm': 1604,
#  'etc free': 620,
#  'bx ip': 237,
#  'ip pm': 1031,
#  'later': 1100,
#  'sorri call': 1945,
#  'call later': 257,
#  'later meet': 1101,
#  'reach': 1688,
#  'seri': 1839,
#  'pick': 1569,
#  'move': 1357,
#  'pain': 1527,
#  'kill': 1073,
#  'way home': 2348,
#  'good': 830,
#  'girl': 793,
#  'situat': 1898,
#  'part': 1532,
#  'check': 325,
#  'took': 2159,
#  'forev': 705,
#  'come': 382,
#  'ok come': 1479,
#  'doubl': 564,
#  'hair': 892,
#  'said': 1783,
#  'wun': 2445,
#  'cut': 473,
#  'short': 1866,
#  'nice': 1424,
#  'advis': 24,
#  'follow': 699,
#  'recent': 1705,
#  'review': 1750,
#  'mob': 1320,
#  'award': 128,
#  'bonu': 190,
#  'award bonu': 129,
#  'prize call': 1652,
#  'song': 1936,
#  'frnd': 748,
#  'rpli': 1769,
#  'send ur': 1833,
#  'complimentari': 400,
#  'trip': 2180,
#  'di': 533,
#  'ls': 1212,
#  'ur award': 2240,
#  'hear': 909,
#  'wah': 2307,
#  'lucki': 1220,
#  'save': 1796,
#  'money': 1341,
#  'hee': 913,
#  'hi': 923,
#  'babe': 136,
#  'im': 1003,
#  'wanna': 2323,
#  'someth': 1931,
#  'xx': 2463,
#  'hi babe': 924,
#  'call free': 251,
#  'that': 2091,
#  'cool': 432,
#  'respect': 1741,
#  'that cool': 2092,
#  'peopl': 1545,
#  'much': 1378,
#  'pa': 1522,
#  'oper': 1501,
#  'job': 1050,
#  'ta': 2049,
#  'ah': 37,
#  'hi hi': 927,
#  'stop': 1995,
#  'urgnt': 2266,
#  'real': 1693,
#  'yo': 2493,
#  'ticket': 2117,
#  'one': 1493,
#  'start': 1983,
#  'came': 278,
#  'bed': 158,
#  'coin': 367,
#  'gotta': 857,
#  'kano': 1062,
#  'il': 1001,
#  'download': 566,
#  'wen': 2378,
#  'wen ur': 2379,
#  'stand': 1979,
#  'close': 356,
#  'anoth': 67,
#  'night': 1427,
#  'spent': 1970,
#  'late': 1099,
#  'afternoon': 32,
#  'mean': 1268,
#  'moro': 1352,
#  'includ': 1014,
#  'smile': 1917,
#  'pleasur': 1598,
#  'troubl': 2181,
#  'rain': 1675,
#  'sum': 2027,
#  'hurt': 987,
#  'someon': 1929,
#  'love see': 1207,
#  'servic': 1844,
#  'repres': 1734,
#  'guarante': 875,
#  'call custom': 250,
#  'custom servic': 472,
#  'servic repres': 1848,
#  'repres pm': 1736,
#  'pm guarante': 1606,
#  'guarante cash': 877,
#  'cash prize': 302,
#  'havent': 907,
#  'plan': 1586,
#  'buy': 234,
#  'show': 1869,
#  'collect': 372,
#  'simpli': 1887,
#  'password': 1539,
#  'verifi': 2280,
#  'fml': 698,
#  'po': 1608,
#  'box': 201,
#  'free rington': 732,
#  'po box': 1609,
#  'box mk': 204,
#  'movi': 1358,
#  'abt': 3,
#  'wat abt': 2337,
#  'load': 1166,
#  'loan': 1167,
#  'wk': 2415,
#  'hol': 940,
#  'forgot': 707,
#  'appoint': 87,
#  'shower': 1874,
#  'caus': 305,
#  'prob': 1656,
#  'need get': 1404,
#  'get home': 780,
#  'coffe': 366,
#  'noth': 1453,
#  'els': 598,
#  'okay': 1487,
#  'price': 1645,
#  'long': 1179,
#  'legal': 1127,
#  'ave': 123,
#  'gone': 827,
#  'drive': 574,
#  'test': 2076,
#  'yet': 2490,
#  'guess': 883,
#  'gave': 763,
#  'men': 1279,
#  'chang': 316,
#  'locat': 1169,
#  'cuz': 475,
#  'page': 1525,
#  'umma': 2222,
#  'life': 1143,
#  'lot': 1193,
#  'dear': 506,
#  'love lot': 1204,
#  'wish': 2405,
#  'birthday': 177,
#  'truli': 2183,
#  'aight': 41,
#  'hit': 931,
#  'get cash': 777,
#  'would': 2436,
#  'address': 17,
#  'consid': 413,
#  'comput': 401,
#  'old': 1490,
#  'better': 169,
#  'lie': 1142,
#  'busi': 233,
#  'research': 1739,
#  'go dinner': 807,
#  'thing': 2095,
#  'scare': 1801,
#  'mah': 1228,
#  'contact': 414,
#  'last': 1094,
#  'draw': 567,
#  'hr': 977,
#  'ppm': 1633,
#  'tri contact': 2177,
#  'contact last': 419,
#  'last weekend': 1098,
#  'weekend draw': 2369,
#  'draw show': 569,
#  'show prize': 1871,
#  'prize guarante': 1654,
#  'guarante call': 876,
#  'code valid': 365,
#  'valid hr': 2277,
#  'hr ppm': 978,
#  'wa': 2306,
#  'anyway': 80,
#  'juz': 1060,
#  'eatin': 591,
#  'weight': 2373,
#  'haha': 890,
#  'happen': 899,
#  'enter': 610,
#  'cabin': 239,
#  'boss': 195,
#  'felt': 670,
#  'askd': 107,
#  'apart': 82,
#  'went': 2380,
#  'enter cabin': 611,
#  'cabin pa': 240,
#  'pa said': 1523,
#  'said happi': 1784,
#  'happi day': 902,
#  'day boss': 495,
#  'boss felt': 196,
#  'felt special': 671,
#  'special askd': 1962,
#  'askd lunch': 108,
#  'lunch lunch': 1224,
#  'lunch invit': 1223,
#  'invit apart': 1027,
#  'apart went': 83,
#  'holiday': 945,
#  'flight': 694,
#  'inc': 1012,
#  'min': 1293,
#  'winner special': 2404,
#  'special select': 1965,
#  'select receiv': 1822,
#  'flight inc': 695,
#  'speak live': 1959,
#  'live oper': 1164,
#  'oper claim': 1502,
#  'must': 1386,
#  'friday': 741,
#  'hmm': 936,
#  'uncl': 2226,
#  'inform': 1019,
#  'school': 1803,
#  'directli': 545,
#  'food': 701,
#  'privat': 1649,
#  'account': 8,
#  'statement': 1984,
#  'identifi': 996,
#  'expir': 644,
#  'privat account': 1650,
#  'account statement': 9,
#  'statement show': 1985,
#  'show unredeem': 1873,
#  'point claim': 1617,
#  'call identifi': 253,
#  'identifi code': 997,
#  'code expir': 363,
#  'landlin': 1089,
#  'urgent mobil': 2263,
#  'mobil award': 1323,
#  'bonu caller': 191,
#  'caller prize': 273,
#  'contact call': 415,
#  'call landlin': 256,
#  'voda': 2297,
#  'number': 1460,
#  'match': 1252,
#  'quot': 1673,
#  'standard': 1980,
#  'app': 84,
#  'today voda': 2142,
#  'voda number': 2298,
#  'number end': 1462,
#  'end select': 602,
#  'receiv award': 1702,
#  'match pleas': 1253,
#  'call quot': 263,
#  'quot claim': 1674,
#  'code standard': 364,
#  'standard rate': 1981,
#  'mu': 1377,
#  'predict': 1638,
#  'wat time': 2339,
#  'time finish': 2122,
#  'sent': 1835,
#  'bother': 197,
#  'del': 519,
#  'bak': 142,
#  'long time': 1181,
#  'give call': 795,
#  'dear call': 507,
#  'answer': 71,
#  'sunshin': 2032,
#  'quiz': 1672,
#  'top': 2160,
#  'soni': 1937,
#  'dvd': 584,
#  'player': 1590,
#  'countri': 443,
#  'ansr': 69,
#  'sp': 1955,
#  'tyron': 2216,
#  'sunshin quiz': 2033,
#  'soni dvd': 1938,
#  'player know': 1591,
#  'ansr sp': 70,
#  'sp tyron': 1956,
#  'laid': 1085,
#  'dog': 555,
#  'direct': 544,
#  'join': 1052,
#  'bt': 222,
#  'txting': 2211,
#  'nt': 1455,
#  'ec': 592,
#  'want get': 2326,
#  'tonight want': 2157,
#  'sent direct': 1836,
#  'ur mob': 2251,
#  'join uk': 1053,
#  'uk largest': 2219,
#  'haf': 889,
#  'yiju': 2491,
#  'activ': 13,
#  'chat': 322,
#  'age': 35,
#  'yr': 2496,
#  'go get': 808,
#  'lazi': 1112,
#  'type': 2214,
#  'lect': 1123,
#  'sir': 1893,
#  'mail': 1230,
#  'sir wait': 1894,
#  'swt': 2047,
#  'tire': 2130,
#  'littl': 1161,
#  'lovabl': 1194,
#  'person': 1556,
#  'coz': 447,
#  'biggest': 173,
#  'heart': 911,
#  'gud': 878,
#  'ni': 1423,
#  'gud ni': 881,
#  'open': 1500,
#  'ya': 2468,
#  'ye see': 2479,
#  'what': 2383,
#  'sexi': 1853,
#  'local': 1168,
#  'luv': 1225,
#  'ltd': 1217,
#  'per msg': 1550,
#  'repli stop': 1731,
#  'stop end': 1996,
#  'begin': 162,
#  'qatar': 1667,
#  'pray': 1637,
#  'hard': 904,
#  'delet': 521,
#  'got job': 851,
#  'wine': 2402,
#  'thk': 2104,
#  'need go': 1405,
#  'shirt': 1862,
#  'sometim': 1934,
#  'dream': 571,
#  'without': 2413,
#  'joy': 1056,
#  'tv': 2193,
#  'becom': 157,
#  'leav': 1120,
#  'hous': 971,
#  'leav hous': 1121,
#  'interview': 1024,
#  'boy': 208,
#  'good boy': 832,
#  'arrang': 100,
#  'new year': 1419,
#  'receiv cash': 1703,
#  'keep': 1065,
#  'safe': 1782,
#  'everyon': 630,
#  'miss alreadi': 1310,
#  'parent': 1529,
#  'hand': 896,
#  'new job': 1414,
#  'excit': 638,
#  'spend': 1969,
#  'invit friend': 1028,
#  'friend repli': 744,
#  'see www': 1818,
#  'www sm': 2451,
#  'stop send': 1999,
#  'send stop': 1832,
#  'stop frnd': 1998,
#  'order': 1513,
#  'content': 425,
#  'goto': 856,
#  'internet': 1023,
#  'menu': 1280,
#  'ur mobil': 2252,
#  'urgent tri': 2265,
#  'avoid': 124,
#  'wit': 2410,
#  'fanci': 655,
#  'complet': 399,
#  'form': 709,
#  'also': 58,
#  'wast': 2335,
#  'bank': 145,
#  'hmmm': 937,
#  'hop': 954,
#  'muz': 1387,
#  'discuss': 548,
#  'liao': 1139,
#  'time come': 2121,
#  'come later': 386,
#  'hell': 914,
#  'cant': 288,
#  'believ': 164,
#  'mr': 1361,
#  'ill': 1002,
#  'bath': 149,
#  'carlo': 295,
#  'got money': 854,
#  'stay': 1987,
#  'til': 2118,
#  'smoke': 1918,
#  'worth': 2433,
#  'doesnt': 554,
#  'log': 1170,
#  'spoke': 1972,
#  'satisfi': 1791,
#  'experi': 643,
#  'lift': 1144,
#  'especi': 618,
#  'studi': 2014,
#  'gr': 858,
#  'trust': 2184,
#  'guy': 885,
#  'bye': 238,
#  'toward': 2167,
#  'boytoy': 209,
#  'get back': 776,
#  'awesom': 135,
#  'minut': 1303,
#  'freephon': 737,
#  'repres freephon': 1735,
#  'freephon pm': 738,
#  'xma': 2461,
#  'time get': 2123,
#  'ju': 1058,
#  'si': 1876,
#  'reach home': 1690,
#  'go bath': 804,
#  'th': 2085,
#  'co uk': 361,
#  'touch': 2164,
#  'deal': 505,
#  'keep touch': 1066,
#  'cours': 445,
#  'howev': 974,
#  'suggest': 2024,
#  'abl': 2,
#  'everi': 626,
#  'settl': 1851,
#  'gr day': 859,
#  'mrng': 1362,
#  'hav': 906,
#  'gud mrng': 880,
#  'nice day': 1425,
#  'stori': 2006,
#  'person stori': 1559,
#  'dead': 504,
#  'tmr': 2132,
#  'orchard': 1512,
#  'mrt': 1363,
#  'kate': 1063,
#  'see tomorrow': 1817,
#  'found': 713,
#  'buck': 227,
#  'gt buck': 868,
#  'darlin': 487,
#  'ive': 1040,
#  'colleg': 375,
#  'love kate': 1201,
#  'success': 2022,
#  'decim': 512,
#  'balanc': 143,
#  'rs': 1770,
#  'transact': 2171,
#  'id': 994,
#  'lt decim': 1214,
#  'decim gt': 513,
#  'rs lt': 1771,
#  'goodmorn': 843,
#  'sleep': 1905,
#  'ga': 757,
#  'dat': 490,
#  'oso': 1517,
#  'cannot': 287,
#  'oredi': 1515,
#  'like dat': 1149,
#  'straight': 2009,
#  'connect': 412,
#  'bill': 174,
#  'give us': 796,
#  'big': 172,
#  'readi': 1692,
#  'get readi': 781,
#  'break': 213,
#  'semest': 1825,
#  'hope great': 959,
#  'noe': 1433,
#  'leh': 1128,
#  'sound': 1950,
#  'head': 908,
#  'slept': 1908,
#  'past': 1540,
#  'easi': 588,
#  'sen': 1826,
#  'exam': 635,
#  'march': 1247,
#  'atm': 114,
#  'regist': 1715,
#  'ok prob': 1482,
#  'import': 1009,
#  'file': 675,
#  'system': 2048,
#  'shop': 1864,
#  'romant': 1762,
#  'nite': 1431,
#  'tc': 2058,
#  'biz': 182,
#  'optout': 1508,
#  'gbp': 767,
#  'mtmsg': 1375,
#  'new mobil': 1415,
#  'txt nokia': 2201,
#  'appreci': 88,
#  'partner': 1535,
#  'career': 294,
#  'star': 1982,
#  'sign': 1881,
#  'compani': 397,
#  'bcoz': 153,
#  'teach': 2061,
#  'good morn': 839,
#  'walk': 2316,
#  'cross': 456,
#  'road': 1759,
#  'side': 1878,
#  'street': 2010,
#  'batteri': 150,
#  'die': 536,
#  'work place': 2426,
#  'flirt': 696,
#  'sam': 1789,
#  'recd': 1699,
#  'name age': 1392,
#  'print': 1648,
#  'bu stop': 226,
#  'wil': 2396,
#  'argument': 95,
#  'lose': 1191,
#  'argu': 94,
#  'kick': 1070,
#  'person dont': 1557,
#  'ur friend': 2243,
#  'secret': 1811,
#  'admir': 18,
#  'reveal': 1748,
#  'secret admir': 1812,
#  'admir look': 19,
#  'look make': 1186,
#  'make contact': 1233,
#  'contact find': 418,
#  'find reveal': 683,
#  'reveal think': 1749,
#  'think ur': 2102,
#  'ur special': 2256,
#  'special call': 1963,
#  'laptop': 1092,
#  'case': 297,
#  'tel': 2066,
#  'meant': 1269,
#  'told': 2144,
#  'face': 649,
#  'fr': 714,
#  'thanx': 2090,
#  'everyth': 631,
#  'websit': 2358,
#  'kalli': 1061,
#  'didnt': 534,
#  'goodnight': 845,
#  'fix': 690,
#  'wake': 2315,
#  'oh ok': 1476,
#  'good night': 840,
#  'congratul': 410,
#  'cd': 308,
#  'voucher': 2303,
#  'gift': 790,
#  'music': 1383,
#  'tnc': 2133,
#  'ldew': 1113,
#  'ppmx': 1634,
#  'congratul ur': 411,
#  'gift guarante': 791,
#  'draw txt': 570,
#  'txt music': 2200,
#  'music tnc': 1385,
#  'tnc www': 2134,
#  'www ldew': 2449,
#  'ldew com': 1114,
#  'com win': 381,
#  'win ppmx': 2401,
#  'ppmx age': 1635,
#  'cal': 244,
#  'hold': 941,
#  'bcum': 154,
#  'angri': 65,
#  'wid': 2391,
#  'dnt': 551,
#  'childish': 331,
#  'true': 2182,
#  'deep': 515,
#  'affect': 27,
#  ...}

# %%
## Output Features
y = pd.get_dummies(messages['label'])

y = y.iloc[:,0].values

y.shape
# Out:
# (5572,)

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

# %%
from sklearn.naive_bayes import MultinomialNB

spam_detect_model = MultinomialNB().fit(X_train,y_train)

# %%
y_pred = spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9802690582959641

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       142
#            1       0.98      0.99      0.99       973
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.94      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# # Creating The TF-IDF Model

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(corpus, y, test_size=0.20)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(max_features = 2500, ngram_range = (1,2))

X_train = tv.fit_transform(X_train).toarray()
X_test = tv.transform(X_test).toarray()

# %%
tv.vocabulary_
# Out:
# {'lol': 1196,
#  'differ': 523,
#  'go': 809,
#  'tri': 2167,
#  'find': 694,
#  'everi': 635,
#  'real': 1699,
#  'life': 1165,
#  'photo': 1559,
#  'ever': 634,
#  'took': 2153,
#  'hi': 946,
#  'girl': 799,
#  'wait': 2313,
#  'text': 2072,
#  'great': 866,
#  'night': 1432,
#  'chat': 311,
#  'send': 1831,
#  'stop': 1985,
#  'servic': 1847,
#  'chat send': 313,
#  'send stop': 1838,
#  'stop stop': 1991,
#  'thank': 2083,
#  'rington': 1758,
#  'order': 1509,
#  'refer': 1715,
#  'number': 1461,
#  'mobil': 1336,
#  'charg': 306,
#  'tone': 2146,
#  'arriv': 92,
#  'pleas': 1582,
#  'call': 225,
#  'custom': 460,
#  'thank rington': 2086,
#  'rington order': 1760,
#  'refer number': 1716,
#  'number mobil': 1464,
#  'mobil charg': 1337,
#  'charg tone': 308,
#  'tone arriv': 2147,
#  'arriv pleas': 93,
#  'pleas call': 1583,
#  'call custom': 230,
#  'custom servic': 462,
#  'mth': 1381,
#  'updat': 2233,
#  'latest': 1129,
#  'orang': 1506,
#  'camera': 262,
#  'video': 2285,
#  'phone': 1554,
#  'free': 732,
#  'save': 1799,
#  'weekend': 2368,
#  'ye': 2470,
#  'opt': 1504,
#  'mobil mth': 1342,
#  'mth updat': 1382,
#  'updat latest': 2234,
#  'video phone': 2288,
#  'phone free': 1556,
#  'free text': 743,
#  'weekend call': 2369,
#  'call text': 248,
#  'text ye': 2080,
#  'wat': 2341,
#  'thought': 2104,
#  'put': 1664,
#  'back': 129,
#  'box': 191,
#  'guarante': 889,
#  'cash': 285,
#  'prize': 1645,
#  'claim': 339,
#  'yr': 2494,
#  'repres': 1740,
#  'pm': 1591,
#  'cost': 426,
#  'guarante cash': 891,
#  'cash prize': 289,
#  'prize claim': 1647,
#  'claim yr': 346,
#  'yr prize': 2495,
#  'prize call': 1646,
#  'servic repres': 1850,
#  'pm cost': 1592,
#  'chennai': 321,
#  'still': 1975,
#  'silent': 1880,
#  'today': 2135,
#  'vodafon': 2301,
#  'end': 607,
#  'select': 1825,
#  'receiv': 1707,
#  'award': 117,
#  'match': 1269,
#  'vodafon number': 2302,
#  'number end': 1463,
#  'end select': 608,
#  'select receiv': 1826,
#  'receiv award': 1708,
#  'train': 2163,
#  'morn': 1361,
#  'much': 1385,
#  'wine': 2402,
#  'sleep': 1901,
#  'well': 2377,
#  'sleep well': 1902,
#  'ok': 1477,
#  'theori': 2092,
#  'test': 2071,
#  'book': 185,
#  'think': 2094,
#  'may': 1281,
#  'coz': 436,
#  'wanna': 2327,
#  'isnt': 1053,
#  'weird': 2375,
#  'know': 1102,
#  'one': 1491,
#  'point': 1601,
#  'sorri': 1935,
#  'gone': 833,
#  'place': 1577,
#  'tomorrow': 2145,
#  'realli': 1702,
#  'mayb': 1282,
#  'leav': 1145,
#  'credit': 442,
#  'card': 278,
#  'get': 785,
#  'ga': 768,
#  'like': 1170,
#  'told': 2143,
#  'get back': 786,
#  'love': 1216,
#  'offic': 1472,
#  'wonder': 2422,
#  'smile': 1909,
#  'yo': 2491,
#  'yo yo': 2492,
#  'someon': 1920,
#  'sure': 2025,
#  'made': 1244,
#  'god': 827,
#  'decid': 493,
#  'time': 2115,
#  'make': 1250,
#  'meet': 1288,
#  'dat': 478,
#  'person': 1549,
#  'till': 2114,
#  'den': 509,
#  'enjoy': 613,
#  'ur': 2235,
#  'time make': 2121,
#  'enjoy ur': 614,
#  'forgot': 723,
#  'ask': 97,
#  'smth': 1912,
#  'da': 466,
#  'present': 1631,
#  'lei': 1152,
#  'want': 2328,
#  'write': 2442,
#  'sign': 1879,
#  'carlo': 282,
#  'say': 1801,
#  'mu': 1384,
#  'lt': 1230,
#  'gt': 878,
#  'minut': 1320,
#  'lt gt': 1232,
#  'gt minut': 884,
#  'class': 347,
#  'happi': 917,
#  'new': 1418,
#  'year': 2478,
#  'happi new': 920,
#  'new year': 1424,
#  'come': 377,
#  'friday': 750,
#  'pongal': 1608,
#  'news': 1425,
#  'work': 2426,
#  'show': 1868,
#  'wot': 2434,
#  'could': 431,
#  'hurt': 1005,
#  'close': 352,
#  'fight': 687,
#  'wit': 2409,
#  'dem': 508,
#  'di': 517,
#  'relat': 1720,
#  'bt': 208,
#  'gud': 892,
#  'want go': 2331,
#  'might': 1308,
#  'less': 1155,
#  'add': 20,
#  'day': 481,
#  'valentin': 2274,
#  'special': 1949,
#  'win': 2398,
#  'quiz': 1672,
#  'take': 2038,
#  'partner': 1531,
#  'trip': 2172,
#  'msg': 1375,
#  'rcvd': 1691,
#  'custcar': 458,
#  'valentin day': 2275,
#  'send go': 1834,
#  'go msg': 819,
#  'msg rcvd': 1377,
#  'fone': 717,
#  'weekli': 2371,
#  'repli': 1732,
#  'www': 2447,
#  'co': 355,
#  'uk': 2214,
#  'origin': 1511,
#  'best': 154,
#  'gbp': 779,
#  'network': 1413,
#  'oper': 1499,
#  'rate': 1685,
#  'appli': 76,
#  'tone repli': 2149,
#  'co uk': 357,
#  'network oper': 1415,
#  'oper rate': 1501,
#  'rate appli': 1686,
#  'meanwhil': 1286,
#  'shit': 1863,
#  'suit': 2014,
#  'give': 801,
#  'us': 2267,
#  'second': 1814,
#  'play': 1579,
#  'jay': 1063,
#  'also': 55,
#  'realiz': 1701,
#  'live': 1185,
#  'anymor': 65,
#  'give us': 803,
#  'school': 1807,
#  'alreadi': 52,
#  'appar': 75,
#  'drive': 570,
#  'inch': 1031,
#  'snow': 1914,
#  'suppos': 2024,
#  'aathi': 0,
#  'dear': 491,
#  'secret': 1815,
#  'admir': 22,
#  'look': 1203,
#  'contact': 406,
#  'reveal': 1751,
#  'ppm': 1622,
#  'secret admir': 1816,
#  'admir look': 23,
#  'look make': 1205,
#  'make contact': 1251,
#  'contact find': 410,
#  'find reveal': 697,
#  'reveal think': 1752,
#  'think ur': 2098,
#  'ur special': 2254,
#  'special call': 1950,
#  'eatin': 595,
#  'later': 1126,
#  'wif': 2394,
#  'fren': 748,
#  'home': 969,
#  'first': 704,
#  'go home': 815,
#  'oop': 1497,
#  'dey': 516,
#  'paid': 1520,
#  'would': 2435,
#  'orchard': 1508,
#  'reach': 1693,
#  'soon': 1934,
#  'escap': 624,
#  'theatr': 2090,
#  'watch': 2346,
#  'go watch': 825,
#  'anoth': 63,
#  'tri make': 2171,
#  'stuff': 2005,
#  'sell': 1828,
#  'tell': 2062,
#  'sec': 1813,
#  'somebodi': 1919,
#  'see': 1818,
#  'want see': 2335,
#  'price': 1637,
#  'oz': 1516,
#  'let': 1157,
#  'let know': 1159,
#  'search': 1812,
#  'tat': 2047,
#  'idk': 1017,
#  'keep': 1085,
#  'sinc': 1883,
#  'move': 1367,
#  'head': 930,
#  'respons': 1746,
#  'tire': 2126,
#  'deal': 490,
#  'bare': 137,
#  'togeth': 2142,
#  'ad': 19,
#  'address': 21,
#  'said': 1786,
#  'right': 1755,
#  'saw': 1800,
#  'possibl': 1614,
#  'die': 521,
#  'oh': 1475,
#  'air': 43,
#  'talent': 2043,
#  'way': 2350,
#  'care': 279,
#  'umma': 2216,
#  'lot': 1212,
#  'love lot': 1222,
#  'huh': 1000,
#  'mean': 1284,
#  'comput': 393,
#  'push': 1662,
#  'like dat': 1171,
#  'old': 1488,
#  'sex': 1854,
#  'bedroom': 148,
#  'year old': 2479,
#  'ho': 962,
#  'use': 2268,
#  'type': 2209,
#  'word': 2424,
#  'first time': 705,
#  'time use': 2124,
#  'type word': 2210,
#  'cool': 421,
#  'fun': 765,
#  'practic': 1626,
#  'babi': 128,
#  'congratul': 402,
#  'winner': 2403,
#  'draw': 562,
#  'code': 358,
#  'prize draw': 1648,
#  'sorri call': 1936,
#  'call later': 238,
#  'later meet': 1127,
#  'gonna': 834,
#  'check': 318,
#  'sale': 1790,
#  'gonna get': 835,
#  'want come': 2329,
#  'come get': 379,
#  'got': 851,
#  'stori': 1997,
#  'person stori': 1551,
#  'side': 1876,
#  'effect': 596,
#  'month': 1357,
#  'last': 1120,
#  'last night': 1121,
#  'line': 1175,
#  'rest': 1747,
#  'dream': 566,
#  'career': 281,
#  'start': 1966,
#  'txt': 2190,
#  'follow': 716,
#  'star': 1965,
#  'fli': 711,
#  'mind': 1318,
#  'friend': 751,
#  'mine': 1319,
#  'friend mine': 753,
#  'question': 1669,
#  'like lt': 1173,
#  'sir': 1888,
#  'sent': 1842,
#  'email': 603,
#  'log': 1192,
#  'messag': 1302,
#  'thing': 2093,
#  'great weekend': 872,
#  'two': 2188,
#  'need': 1409,
#  'def': 499,
#  'readi': 1698,
#  'still need': 1976,
#  'need get': 1410,
#  'get cash': 787,
#  'normal': 1452,
#  'tuesday': 2183,
#  'bishan': 166,
#  'tot': 2156,
#  'ah': 38,
#  'confus': 399,
#  'doesnt': 545,
#  'wrong': 2444,
#  'sort': 1940,
#  'invit': 1044,
#  'tho': 2102,
#  'money': 1356,
#  'somewher': 1928,
#  'help': 941,
#  'noth': 1454,
#  'name': 1399,
#  'buy': 217,
#  'apart': 73,
#  'go buy': 812,
#  'freefon': 744,
#  'gift': 796,
#  'speak': 1946,
#  'speak live': 1947,
#  'live oper': 1187,
#  'kalli': 1080,
#  'wont': 2423,
#  'nd': 1405,
#  'heart': 933,
#  'get free': 788,
#  'excel': 647,
#  'spent': 1953,
#  'travel': 2165,
#  'gt year': 888,
#  'never': 1417,
#  'alon': 50,
#  'weight': 2374,
#  'tear': 2055,
#  'fall': 664,
#  'eye': 658,
#  'alway': 56,
#  'rememb': 1724,
#  'stupid': 2006,
#  'share': 1858,
#  'bslvyl': 205,
#  'come ur': 384,
#  'ur heart': 2243,
#  'serv': 1846,
#  'yesterday': 2485,
#  'hope': 974,
#  'hope enjoy': 975,
#  'true': 2174,
#  'wil': 2397,
#  'though': 2103,
#  'often': 1474,
#  'mistak': 1328,
#  'valu': 2279,
#  'miss': 1323,
#  'town': 2162,
#  'ju': 1076,
#  'mrt': 1373,
#  'exam': 645,
#  'week': 2362,
#  'go write': 826,
#  'offer': 1469,
#  'plu': 1588,
#  'daddi': 469,
#  'eat': 594,
#  'long': 1200,
#  'muz': 1395,
#  'chang': 304,
#  'plan': 1578,
#  'liao': 1161,
#  'yan': 2465,
#  'jiu': 1067,
#  'go back': 810,
#  'yan jiu': 2466,
#  'hey': 942,
#  'spk': 1954,
#  'blackberri': 171,
#  'torch': 2155,
#  'nigeria': 1431,
#  'dad': 468,
#  'bb': 141,
#  'anyon': 66,
#  'dont': 550,
#  'kick': 1090,
#  'finish': 702,
#  'wat time': 2344,
#  'gram': 863,
#  'usual': 2271,
#  'run': 1778,
#  'half': 908,
#  'almost': 49,
#  'whole': 2391,
#  'quit': 1671,
#  'ex': 643,
#  'ring': 1757,
#  'around': 88,
#  'mob': 1333,
#  'collect': 366,
#  'nokia': 1439,
#  'logo': 1195,
#  'pic': 1560,
#  'ur mob': 2248,
#  'plu free': 1589,
#  'grin': 875,
#  'buzz': 218,
#  'ass': 102,
#  'feel': 677,
#  'around lt': 89,
#  'except': 648,
#  'disturb': 539,
#  'talk': 2044,
#  'yet': 2486,
#  'touch': 2158,
#  'ru': 1775,
#  'hous': 989,
#  'keep touch': 1086,
#  'confid': 397,
#  'amp': 59,
#  'askd': 99,
#  'sit': 1891,
#  'aftr': 34,
#  'sat': 1793,
#  'student': 2003,
#  'hurri': 1004,
#  'didnt': 519,
#  'even': 632,
#  'what': 2385,
#  'problem': 1654,
#  'least': 1144,
#  'dear call': 492,
#  'th': 2081,
#  'mate': 1271,
#  'final': 692,
#  'happen': 915,
#  'beer': 149,
#  'cheaper': 315,
#  'expect': 651,
#  'drink': 569,
#  'dude': 576,
#  'hw': 1007,
#  'reali': 1700,
#  'gd': 780,
#  'meet call': 1289,
#  'argument': 85,
#  'situat': 1893,
#  'lose': 1210,
#  'argu': 84,
#  'correct': 425,
#  'person dont': 1550,
#  'ur friend': 2241,
#  'that': 2088,
#  'bit': 167,
#  'good': 836,
#  'idea': 1013,
#  'pub': 1660,
#  'went': 2382,
#  'fast': 672,
#  'asleep': 101,
#  'take care': 2039,
#  'campu': 267,
#  'librari': 1162,
#  'urgent': 2259,
#  'membership': 1297,
#  'net': 1411,
#  'pobox': 1597,
#  'ldnw': 1140,
#  'week free': 2364,
#  'txt word': 2203,
#  'xma': 2458,
#  'either': 600,
#  'cd': 295,
#  'voucher': 2307,
#  'entri': 619,
#  'music': 1391,
#  'tnc': 2131,
#  'ldew': 1137,
#  'com': 374,
#  'ppmx': 1623,
#  'age': 35,
#  'subscript': 2011,
#  'ur award': 2236,
#  'award either': 121,
#  'cd gift': 296,
#  'gift voucher': 798,
#  'free entri': 736,
#  'entri weekli': 620,
#  'weekli draw': 2373,
#  'draw txt': 565,
#  'txt music': 2195,
#  'music tnc': 1393,
#  'tnc www': 2132,
#  'www ldew': 2450,
#  'ldew com': 1138,
#  'com win': 376,
#  'win ppmx': 2400,
#  'ppmx age': 1624,
#  'del': 501,
#  'bak': 132,
#  'long time': 1201,
#  'give call': 802,
#  'princess': 1640,
#  'sexi': 1855,
#  'mum': 1386,
#  'food': 718,
#  'privat': 1643,
#  'account': 10,
#  'statement': 1969,
#  'un': 2217,
#  'redeem': 1713,
#  'identifi': 1014,
#  'expir': 654,
#  'privat account': 1644,
#  'account statement': 11,
#  'statement show': 1970,
#  'show un': 1870,
#  'un redeem': 2218,
#  'redeem point': 1714,
#  'point call': 1602,
#  'call identifi': 234,
#  'identifi code': 1015,
#  'code expir': 359,
#  'seri': 1844,
#  'fanci': 666,
#  'tomo': 2144,
#  'aight': 41,
#  'sound': 1941,
#  'post': 1615,
#  'bad': 130,
#  'gal': 769,
#  'babe': 126,
#  'awak': 116,
#  'act': 15,
#  'hear': 931,
#  'attempt': 105,
#  'contract': 416,
#  'top': 2154,
#  'nd attempt': 1406,
#  'chosen': 331,
#  'transfer': 2164,
#  'els': 601,
#  'chosen receiv': 332,
#  'fix': 707,
#  'teeth': 2060,
#  'asap': 95,
#  'ok take': 1483,
#  'bed': 147,
#  'thank god': 2084,
#  'beauti': 144,
#  'wife': 2395,
#  'come back': 378,
#  'wait till': 2317,
#  'hot': 985,
#  'fantasi': 667,
#  'per': 1542,
#  'min': 1311,
#  'ntt': 1458,
#  'ltd': 1234,
#  'po': 1595,
#  'croydon': 446,
#  'cr': 437,
#  'wb': 2351,
#  'hot live': 986,
#  'live fantasi': 1186,
#  'fantasi call': 668,
#  'call per': 243,
#  'per min': 1543,
#  'min ntt': 1313,
#  'ntt ltd': 1459,
#  'ltd po': 1235,
#  'po box': 1596,
#  'box croydon': 192,
#  'croydon cr': 447,
#  'cr wb': 438,
#  'hiya': 955,
#  'pay': 1537,
#  'surpris': 2029,
#  'balanc': 133,
#  'dine': 530,
#  'ladi': 1110,
#  'sun': 2017,
#  'hello': 940,
#  'im': 1021,
#  'bore': 186,
#  'id': 1012,
#  'tv': 2186,
#  'someth': 1924,
#  'excit': 649,
#  'anyth': 67,
#  'cancer': 269,
#  'damn': 471,
#  'poor': 1609,
#  'stand': 1962,
#  'chanc': 301,
#  'decim': 494,
#  'pay lt': 1538,
#  'lt decim': 1231,
#  'decim gt': 495,
#  'probabl': 1652,
#  'next': 1426,
#  'come home': 380,
#  'game': 770,
#  'answer': 64,
#  'colour': 370,
#  'rpli': 1772,
#  'shall': 1856,
#  'havent': 928,
#  'car': 277,
#  'dinner': 531,
#  'leh': 1151,
#  'tonight': 2151,
#  'go dinner': 813,
#  'done': 549,
#  'amaz': 57,
#  'letter': 1160,
#  'dirti': 535,
#  'room': 1766,
#  'moon': 1359,
#  'result': 1748,
#  'lie': 1164,
#  'mother': 1364,
#  'law': 1135,
#  'woman': 2421,
#  'bonu': 182,
#  'caller': 252,
#  'nation': 1401,
#  'urgent mobil': 2262,
#  'award bonu': 118,
#  'bonu caller': 183,
#  'caller prize': 254,
#  'prize nd': 1650,
#  'attempt contact': 106,
#  'contact call': 407,
#  'bt nation': 209,
#  'nation rate': 1402,
#  'kindli': 1097,
#  'loan': 1190,
#  'lor': 1207,
#  'goin': 832,
#  'nice': 1429,
#  'stay': 1972,
#  'wish': 2404,
#  'moji': 1351,
#  'wish great': 2405,
#  'great day': 867,
#  'okay': 1485,
#  'pl': 1569,
#  'natur': 1403,
#  'actual': 18,
#  'troubl': 2173,
#  'convinc': 419,
#  'tel': 2061,
#  'twice': 2187,
#  'read': 1696,
#  'trust': 2176,
#  'ugh': 2213,
#  'mon': 1354,
#  'hun': 1001,
#  'date': 479,
#  'guy': 899,
#  'met': 1305,
#  'far': 671,
#  'how': 991,
#  'everyon': 640,
#  'come tomorrow': 383,
#  'man': 1257,
#  'teach': 2052,
#  'abi': 1,
#  'say hi': 1803,
#  'yup': 2497,
#  'fri': 749,
#  'karaok': 1082,
#  'one day': 1492,
#  'seriou': 1845,
#  'joy': 1073,
#  'father': 674,
#  'john': 1069,
#  'joy father': 1074,
#  'dun': 578,
#  'wan': 2321,
#  'rite': 1761,
#  'dun wan': 584,
#  'wan meet': 2324,
#  'everybodi': 639,
#  'batteri': 140,
#  'afternoon': 32,
#  'sunshin': 2020,
#  'breath': 201,
#  'good afternoon': 837,
#  'frnd': 757,
#  'avoid': 113,
#  'ard': 81,
#  'handset': 912,
#  'anytim': 69,
#  'unlimit': 2226,
#  'camcord': 258,
#  'tri contact': 2168,
#  'contact repli': 413,
#  'repli offer': 1736,
#  'video handset': 2287,
#  'handset anytim': 913,
#  'anytim network': 70,
#  'network min': 1414,
#  'min unlimit': 1317,
#  'unlimit text': 2227,
#  'camcord repli': 259,
#  'repli call': 1733,
#  'leav hous': 1146,
#  'subscrib': 2010,
#  'content': 415,
#  'mobil content': 1338,
#  'day send': 486,
#  'doubl': 559,
#  'must': 1394,
#  'know well': 1104,
#  'notic': 1455,
#  'tenerif': 2067,
#  'holiday': 965,
#  'landlin': 1114,
#  'tc': 2049,
#  'sae': 1782,
#  'wx': 2454,
#  'tenerif holiday': 2068,
#  'holiday cash': 967,
#  'award call': 119,
#  'call landlin': 237,
#  'send lt': 1835,
#  'gt min': 883,
#  'mark': 1265,
#  'forev': 721,
#  'pick': 1561,
#  'pain': 1521,
#  'hold': 964,
#  'bout': 190,
#  'short': 1866,
#  'cute': 464,
#  'mrng': 1372,
#  'dont tri': 554,
#  'gud mrng': 894,
#  'away': 124,
#  'system': 2036,
#  'si': 1874,
#  'wnt': 2419,
#  'vri': 2310,
#  'hv': 1006,
#  'lac': 1109,
#  'prob': 1651,
#  'gt lac': 881,
#  'sad': 1780,
#  'darlin': 476,
#  'hi darlin': 949,
#  'ok ok': 1480,
#  'unless': 2225,
#  'finger': 701,
#  'difficult': 524,
#  'pilat': 1565,
#  'intro': 1043,
#  'noe': 1438,
#  'sch': 1806,
#  'red': 1712,
#  'green': 873,
#  'black': 170,
#  'kiss': 1099,
#  'realli need': 1704,
#  'dvd': 587,
#  'bid': 158,
#  'visit': 2297,
#  'sm': 1906,
#  'ac': 5,
#  'sm ac': 1907,
#  'pleasur': 1586,
#  'tea': 2051,
#  'shop': 1864,
#  'qatar': 1665,
#  'rakhesh': 1681,
#  'indian': 1035,
#  'respect': 1744,
#  'regard': 1717,
#  'pleas send': 1584,
#  'forum': 726,
#  'fool': 719,
#  'friendship': 755,
#  'teacher': 2053,
#  'children': 324,
#  'birthday': 163,
#  'christma': 333,
#  'wish happi': 2406,
#  'day happi': 485,
#  'happi valentin': 922,
#  'happi birthday': 918,
#  'gt good': 880,
#  'good morn': 841,
#  'group': 877,
#  'mail': 1248,
#  'face': 660,
#  'quick': 1670,
#  'tell ur': 2065,
#  'accid': 8,
#  'via': 2284,
#  'speak soon': 1948,
#  'lot love': 1213,
#  'shirt': 1862,
#  'blue': 178,
#  'thk': 2100,
#  'late': 1125,
#  'definit': 500,
#  'got money': 856,
#  'throw': 2106,
#  'luv': 1241,
#  'brother': 204,
#  'gay': 776,
#  'lmao': 1188,
#  'boy': 197,
#  'xxx': 2460,
#  'direct': 533,
#  'porn': 1611,
#  'hr': 995,
#  'wc': 2353,
#  'xx': 2459,
#  'ur phone': 2251,
#  'stop text': 1992,
#  'wc xx': 2354,
#  'lunch': 1240,
#  'settl': 1853,
#  'gr': 861,
#  'gr day': 862,
#  'angri': 61,
#  'busi': 216,
#  'dun like': 582,
#  'nope': 1449,
#  'watch tv': 2348,
#  'lover': 1225,
#  'goe': 829,
#  'job': 1068,
#  'wake': 2319,
#  'slave': 1900,
#  'teas': 2056,
#  'across': 13,
#  'sea': 1811,
#  'new job': 1419,
#  'teas kiss': 2057,
#  'kiss across': 1100,
#  'across sea': 14,
#  'wait call': 2314,
#  'doin': 547,
#  'full': 762,
#  'joke': 1071,
#  'seem': 1823,
#  'holla': 968,
#  'condit': 396,
#  'freephon': 746,
#  'repres freephon': 1741,
#  'freephon pm': 747,
#  'pm guarante': 1593,
#  'ym': 2490,
#  'activ': 17,
#  'version': 2282,
#  'believ': 152,
#  'dun believ': 579,
#  'rush': 1779,
#  'oki': 1486,
#  'oki lor': 1487,
#  'regret': 1719,
#  'inform': 1037,
#  'kerala': 1088,
#  'ye pleas': 2471,
#  'energi': 609,
#  'high': 952,
#  'strong': 2002,
#  'an': 60,
#  'door': 557,
#  'eve': 631,
#  'sure get': 2026,
#  'great week': 871,
#  'mom': 1352,
#  'set': 1851,
#  'fill': 690,
#  'belli': 153,
#  'loverboy': 1226,
#  'sigh': 1877,
#  'miss alreadi': 1324,
#  'current': 456,
#  'moro': 1363,
#  'includ': 1032,
#  'sheet': 1860,
#  'onward': 1496,
#  'space': 1945,
#  'becom': 146,
#  'issu': 1054,
#  'want need': 2333,
#  'look like': 1204,
#  'earli': 588,
#  'yay': 2469,
#  'sister': 1890,
#  'kid': 1091,
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

spam_tfidf_model = MultinomialNB().fit(X_train, y_train)

# %%
#prediction
y_pred = spam_tfidf_model.predict(X_test)

# %%
score = accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9811659192825112

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       132
#            1       1.00      0.98      0.99       983
#
#     accuracy                           0.98      1115
#    macro avg       0.93      0.99      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#prediction
y_pred = classifier.predict(X_test)

# %%
score = accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9829596412556054

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       132
#            1       1.00      0.98      0.99       983
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.99      0.96      1115
# weighted avg       0.99      0.98      0.98      1115

# %% [markdown]
# # Word2vec Implementation

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')
# Out:
# [===========---------------------------------------] 22.7% 377.0/1662.8MB downloaded

# %%
# Lemmatization

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
corpus = []

for i in range(len(messages)):
  review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
  review = review.lower()
  review = review.split()
  review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words("english"))]
  review = ' '.join(review)
  corpus.append(review)

# %%
from nltk import sent_tokenize

from gensim.utils import simple_preprocess

# %%
corpus[0]
# Out:
# 'go jurong point crazy available bugis n great world la e buffet cine got amore wat'

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = []

for sent in corpus:
  sent_token = sent_tokenize(sent)
  for sent in sent_token:
    words.append(simple_preprocess(sent))

# %%
print(len(words))
# Out:
# 5564

# %%
words
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'go', 'usf', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   'week',
#   'word',
#   'back',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'selected',
#   'receivea',
#   'prize',
#   'reward',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour'],
#  ['mobile',
#   'month',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'mobile',
#   'camera',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['gonna',
#   'home',
#   'soon',
#   'want',
#   'talk',
#   'stuff',
#   'anymore',
#   'tonight',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'win',
#   'cash',
#   'pound',
#   'txt',
#   'csh',
#   'send',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'week',
#   'free',
#   'membership',
#   'prize',
#   'jackpot',
#   'txt',
#   'word',
#   'claim',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['searching',
#   'right',
#   'word',
#   'thank',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'help',
#   'granted',
#   'fulfil',
#   'promise',
#   'wonderful',
#   'blessing',
#   'time'],
#  ['date', 'sunday'],
#  ['use',
#   'credit',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'message',
#   'click',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching'],
#  ['eh', 'remember', 'spell', 'name', 'yes', 'naughty', 'make', 'wet'],
#  ['fine', 'way', 'feel', 'way', 'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'eg',
#   'england',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['seriously', 'spell', 'name'],
#  ['going', 'try', 'month', 'ha', 'ha', 'joking'],
#  ['pay', 'first', 'lar', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff', 'alright', 'way', 'meet', 'sooner'],
#  ['forced',
#   'eat',
#   'slice',
#   'really',
#   'hungry',
#   'tho',
#   'suck',
#   'mark',
#   'getting',
#   'worried',
#   'know',
#   'sick',
#   'turn',
#   'pizza',
#   'lol'],
#  ['lol', 'always', 'convincing'],
#  ['catch',
#   'bus',
#   'frying',
#   'egg',
#   'make',
#   'tea',
#   'eating',
#   'mom',
#   'left',
#   'dinner',
#   'feel',
#   'love'],
#  ['back', 'amp', 'packing', 'car', 'let', 'know', 'room'],
#  ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol'],
#  ['wait', 'still', 'clear', 'sure', 'sarcastic', 'want', 'live'],
#  ['yeah',
#   'got',
#   'apologetic',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'till',
#   'go',
#   'badly',
#   'cheer'],
#  ['tell', 'anything'],
#  ['fear', 'fainting', 'housework', 'quick', 'cuppa'],
#  ['thanks',
#   'subscription',
#   'ringtone',
#   'uk',
#   'mobile',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'replying',
#   'yes',
#   'reply',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'timing',
#   'msg',
#   'xuhui',
#   'going',
#   'learn',
#   'nd',
#   'may',
#   'lesson'],
#  ['oops', 'let', 'know', 'roommate', 'done'],
#  ['see', 'letter', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'saturday',
#   'go',
#   'texting',
#   'see',
#   'decided',
#   'anything',
#   'tomo',
#   'trying',
#   'invite',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'watt',
#   'wanted',
#   'sure',
#   'great',
#   'weekend',
#   'abiola'],
#  ['forget',
#   'tell',
#   'want',
#   'need',
#   'crave',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'tried',
#   'call',
#   'reply',
#   'sm',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'delivery',
#   'tomorrow'],
#  ['seeing'],
#  ['great', 'hope', 'like', 'man', 'well', 'endowed', 'lt', 'gt', 'inch'],
#  ['call', 'message', 'missed', 'call'],
#  ['get', 'hep', 'immunisation', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going'],
#  ['yeah', 'hopefully', 'tyler', 'could', 'maybe', 'ask', 'around', 'bit'],
#  ['know',
#   'stubborn',
#   'even',
#   'want',
#   'go',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'weak',
#   'sucker',
#   'hospital',
#   'weak',
#   'sucker'],
#  ['thinked', 'first', 'time', 'saw', 'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'crashing',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'embarassed',
#   'accomodations',
#   'thought',
#   'liked',
#   'since',
#   'best',
#   'could',
#   'always',
#   'seemed',
#   'happy',
#   'cave',
#   'sorry',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'room',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lt', 'url', 'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'call', 'later', 'meeting'],
#  ['tell', 'reached'],
#  ['yes', 'gauti', 'sehwag', 'odi', 'series'],
#  ['gonna', 'pick', 'burger', 'way', 'home', 'even', 'move', 'pain', 'killing'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation', 'seeker'],
#  ['part', 'checking', 'iq'],
#  ['sorry', 'roommate', 'took', 'forever', 'ok', 'come'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'said',
#   'cut',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'pleased',
#   'advise',
#   'following',
#   'recent',
#   'review',
#   'mob',
#   'awarded',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'song',
#   'dedicated',
#   'day',
#   'song',
#   'dedicate',
#   'send',
#   'ur',
#   'valuable',
#   'frnds',
#   'first',
#   'rply'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'claim',
#   'txt',
#   'dis',
#   'morefrmmob',
#   'aj'],
#  ['hear', 'new', 'divorce', 'barbie', 'come', 'ken', 'stuff'],
#  ['plane', 'give', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'save', 'money', 'hee'],
#  ['finished', 'class'],
#  ['hi', 'babe', 'im', 'home', 'wanna', 'something', 'xx'],
#  ['performed'],
#  ['call'],
#  ['waiting', 'machan', 'call', 'free'],
#  ['thats', 'cool', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['like', 'people', 'much', 'shy', 'pa'],
#  ['operate', 'lt', 'gt'],
#  ['still', 'looking', 'job', 'much', 'ta', 'earn'],
#  ['sorry', 'call', 'later'],
#  ['call', 'ah'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'later', 'network', 'urgnt', 'sm'],
#  ['real',
#   'getting',
#   'yo',
#   'need',
#   'ticket',
#   'one',
#   'jacket',
#   'done',
#   'already',
#   'used',
#   'multis'],
#  ['yes',
#   'started',
#   'send',
#   'request',
#   'make',
#   'pain',
#   'came',
#   'back',
#   'back',
#   'bed',
#   'double',
#   'coin',
#   'factory',
#   'gotta',
#   'cash',
#   'nitros'],
#  ['really', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah', 'stand', 'close', 'tho', 'catch', 'something'],
#  ['sorry',
#   'pain',
#   'ok',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'casualty',
#   'mean',
#   'done',
#   'stuff',
#   'moro',
#   'includes',
#   'time',
#   'sheet',
#   'sorry'],
#  ['smile',
#   'pleasure',
#   'smile',
#   'pain',
#   'smile',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['havent',
#   'planning',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'got',
#   'show',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see', 'finish', 'load', 'loan', 'pay'],
#  ['hi',
#   'wk',
#   'ok',
#   'hols',
#   'yes',
#   'bit',
#   'run',
#   'forgot',
#   'hairdresser',
#   'appointment',
#   'four',
#   'need',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'cause',
#   'prob'],
#  ['see', 'cup', 'coffee', 'animation'],
#  ['please', 'text', 'anymore', 'nothing', 'else', 'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'legal',
#   'wen',
#   'pick',
#   'ave',
#   'am',
#   'xx'],
#  ['still', 'looking', 'car', 'buy', 'gone', 'driving', 'test', 'yet'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['wow',
#   'right',
#   'mean',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'changed',
#   'search',
#   'location',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'wish',
#   'birthday',
#   'thanks',
#   'making',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'considering',
#   'computer',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'mom',
#   'like',
#   'better',
#   'lying',
#   'always',
#   'one',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'busy'],
#  ['plural', 'noun', 'research'],
#  ['going', 'dinner', 'msg'],
#  ['ok',
#   'wif',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'loud'],
#  ['gent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'formal',
#   'anyway',
#   'fine',
#   'juz',
#   'tt',
#   'eatin',
#   'much',
#   'puttin',
#   'weight',
#   'haha',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'uncle',
#   'informed',
#   'paying',
#   'school',
#   'directly',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'account',
#   'statement',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'final',
#   'try',
#   'contact',
#   'call',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['new', 'address', 'apple', 'pair', 'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'selected',
#   'receive',
#   'award',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['going', 'sao', 'mu', 'today', 'done'],
#  ['predict', 'wat', 'time', 'finish', 'buying'],
#  ['good', 'stuff'],
#  ['know',
#   'yetunde',
#   'sent',
#   'money',
#   'yet',
#   'sent',
#   'text',
#   'bother',
#   'sending',
#   'dont',
#   'involve',
#   'anything',
#   'imposed',
#   'anything',
#   'first',
#   'place',
#   'apologise'],
#  ['room'],
#  ['hey',
#   'girl',
#   'hope',
#   'well',
#   'del',
#   'bak',
#   'long',
#   'time',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['much', 'cost'],
#  ['home'],
#  ['dear', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'algarve',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'nt',
#   'ec',
#   'msg'],
#  ['haf', 'msn', 'yijue', 'hotmail', 'com'],
#  ['call', 'meet'],
#  ['check', 'room', 'befor', 'activity'],
#  ['rcv',
#   'msg',
#   'chat',
#   'svc',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'yr',
#   'network',
#   'try'],
#  ['got', 'lazy', 'type', 'forgot', 'lect', 'saw', 'pouch', 'like', 'nice'],
#  ['text', 'way'],
#  ['sir', 'waiting', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'pls', 'open', 'back'],
#  ['yes', 'see', 'ya', 'dot'],
#  ['whats', 'staff', 'name', 'taking', 'class'],
#  ['freemsg',
#   'replied',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'live',
#   'local',
#   'luv',
#   'hear',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'end'],
#  ['ummma', 'call', 'check', 'life', 'begin', 'qatar', 'pls', 'pray', 'hard'],
#  ['deleted', 'contact'],
#  ['sindu', 'got', 'job', 'birla', 'soft'],
#  ['wine', 'flowing', 'nevering'],
#  ['yup', 'thk', 'cine', 'better', 'co', 'need', 'go', 'plaza', 'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['everywhere',
#   'dirt',
#   'floor',
#   'window',
#   'even',
#   'shirt',
#   'sometimes',
#   'open',
#   'mouth',
#   'come',
#   'flowing',
#   'dream',
#   'world',
#   'without',
#   'half',
#   'chore',
#   'time',
#   'joy',
#   'lot',
#   'tv',
#   'show',
#   'see',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'mist',
#   'time',
#   'done',
#   'become',
#   'one'],
#  ['aaooooright', 'work'],
#  ['leaving', 'house'],
#  ['hello',
#   'love',
#   'get',
#   'interview',
#   'today',
#   'happy',
#   'good',
#   'boy',
#   'think',
#   'missing'],
#  ['customer',
#   'service',
#   'annoncement',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'please',
#   'call',
#   'arrange',
#   'delivery'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'already',
#   'envy',
#   'everyone',
#   'see',
#   'real',
#   'life'],
#  ['new', 'car', 'house', 'parent', 'new', 'job', 'hand'],
#  ['love', 'excited', 'day', 'spend', 'make', 'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'inviting',
#   'friend',
#   'reply',
#   'yes',
#   'see',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'way',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'ur', 'point', 'culture', 'module', 'already'],
#  ['urgent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr'],
#  ['hi',
#   'frnd',
#   'best',
#   'way',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'beloved',
#   'one'],
#  ['great', 'escape', 'fancy', 'bridge', 'need', 'lager', 'see', 'tomo'],
#  ['yes', 'completely', 'form', 'clark', 'also', 'utter', 'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard',
#   'ya',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'discus',
#   'liao'],
#  ['time', 'coming', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'forgot',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'spanish',
#   'begin'],
#  ['well', 'gonna', 'finish', 'bath', 'good', 'fine', 'night'],
#  ['let', 'know', 'got', 'money', 'carlos', 'make', 'call'],
#  ['still', 'going', 'mall'],
#  ['turn',
#   'friend',
#   'staying',
#   'whole',
#   'show',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   'lt',
#   'gt',
#   'worth'],
#  ['text', 'doesnt', 'reply', 'let', 'know', 'log'],
#  ['hi',
#   'spoke',
#   'maneesha',
#   'like',
#   'know',
#   'satisfied',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'yes'],
#  ['lifted',
#   'hope',
#   'offer',
#   'money',
#   'need',
#   'especially',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studying',
#   'anyways',
#   'gr',
#   'weekend'],
#  ['lol', 'trust'],
#  ['ok', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['guy', 'close'],
#  ['going', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'finding',
#   'job',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'net',
#   'mummy',
#   'boytoy',
#   'miss'],
#  ['haha', 'awesome', 'minute'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['got', 'xmas', 'radio', 'time', 'get'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'finish'],
#  ['unique',
#   'enough',
#   'find',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   'joined',
#   'league',
#   'people',
#   'dont',
#   'keep',
#   'touch',
#   'mean',
#   'great',
#   'deal',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'personal',
#   'cost',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'course'],
#  ['stop',
#   'however',
#   'suggest',
#   'stay',
#   'someone',
#   'able',
#   'give',
#   'or',
#   'every',
#   'stool'],
#  ['hope', 'settled', 'new', 'school', 'year', 'wishin', 'gr', 'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['got', 'person', 'story'],
#  ['hamster', 'dead', 'hey', 'tmr', 'meet', 'pm', 'orchard', 'mrt'],
#  ['hi',
#   'kate',
#   'evening',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'xxx'],
#  ['found', 'enc', 'lt', 'gt'],
#  ['sent', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'txt',
#   'finish',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refilled',
#   'successfully',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'lt',
#   'decimal',
#   'gt',
#   'transaction',
#   'id',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'alter', 'ok'],
#  ['say',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['please',
#   'give',
#   'connection',
#   'today',
#   'lt',
#   'decimal',
#   'gt',
#   'refund',
#   'bill'],
#  ['shoot', 'big', 'load', 'get', 'ready'],
#  ['bruv', 'hope', 'great', 'break', 'rewarding', 'semester'],
#  ['home', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'noe', 'leh'],
#  ['sound', 'great', 'home'],
#  ['finally', 'match', 'heading', 'towards', 'draw', 'prediction'],
#  ['tired', 'slept', 'well', 'past', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'good'],
#  ['take', 'exam', 'march'],
#  ['yeah',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'register',
#   'sure',
#   'anyway',
#   'help',
#   'let',
#   'know',
#   'sure',
#   'ready'],
#  ['ok', 'prob', 'take', 'ur', 'time'],
#  ['called',
#   'ubandu',
#   'run',
#   'without',
#   'installing',
#   'hard',
#   'disk',
#   'use',
#   'copy',
#   'important',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop'],
#  ['sorry', 'call', 'later'],
#  ['say',
#   'leh',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'collect',
#   'today',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would', 'really', 'appreciate', 'call', 'need', 'someone', 'talk'],
#  ['meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'ur',
#   'career',
#   'flyng',
#   'start',
#   'find',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'strict',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'conduct',
#   'exam',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right'],
#  ['dear', 'going', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah'],
#  ['yes', 'tv', 'always', 'available', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'join',
#   'reply',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['printed', 'oh', 'lt', 'gt', 'come', 'upstairs'],
#  ['ill', 'little', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['wil', 'reach'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'loses',
#   'person',
#   'dont',
#   'argue',
#   'ur',
#   'friend',
#   'kick',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['tomarrow', 'final', 'hearing', 'laptop', 'case', 'cant'],
#  ['tel', 'avent', 'done', 'sportsx'],
#  ['okay', 'shining', 'meant', 'signing', 'sound', 'better'],
#  ['although',
#   'told',
#   'dat',
#   'baig',
#   'face',
#   'watch',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   'done',
#   'today',
#   'touched'],
#  ['remember', 'old', 'commercial'],
#  ['late', 'said', 'website', 'dont', 'slipper'],
#  ['asked', 'call', 'ok'],
#  ['kallis', 'wont', 'bat', 'nd', 'inning'],
#  ['didnt',
#   'work',
#   'oh',
#   'ok',
#   'goodnight',
#   'fix',
#   'ready',
#   'time',
#   'wake',
#   'dearly',
#   'missed',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'seriously',
#   'coz',
#   'angry',
#   'childish',
#   'true',
#   'way',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'nice',
#   'day',
#   'da'],
#  ['ups',
#   'day',
#   'also',
#   'shipping',
#   'company',
#   'take',
#   'wks',
#   'way',
#   'usps',
#   'take',
#   'week',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff'],
#  ['back', 'lemme', 'know', 'ready'],
#  ['necessarily', 'expect', 'done', 'get', 'back', 'though', 'headin'],
#  ['mmm', 'yummy', 'babe', 'nice', 'jolt', 'suzy'],
#  ['lover', 'need'],
#  ['tried',
#   'contact',
#   'reply',
#   'offer',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'call'],
#  ['parked', 'next', 'mini', 'coming', 'today', 'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'co',
#   'si',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['luton', 'ring', 'ur', 'around'],
#  ['hey',
#   'really',
#   'horny',
#   'want',
#   'chat',
#   'see',
#   'naked',
#   'text',
#   'hot',
#   'text',
#   'charged',
#   'pm',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['dint', 'come'],
#  ['wana', 'plan', 'trip', 'sometme'],
#  ['sure', 'yet', 'still', 'trying', 'get', 'hold'],
#  ['ur',
#   'ringtone',
#   'service',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'club',
#   'mobile',
#   'com',
#   'choose',
#   'content',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['evo', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'uk',
#   'single',
#   'chart',
#   'mobile',
#   'week',
#   'choose',
#   'top',
#   'quality',
#   'ringtone',
#   'message',
#   'free',
#   'charge'],
#  ['come', 'mu', 'sorting', 'narcotic', 'situation'],
#  ['night',
#   'ended',
#   'another',
#   'day',
#   'morning',
#   'come',
#   'special',
#   'way',
#   'may',
#   'smile',
#   'like',
#   'sunny',
#   'ray',
#   'leaf',
#   'worry',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'genuine',
#   'hmv',
#   'voucher',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'send',
#   'hmv',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['objection', 'bf', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesome', 'see', 'bit'],
#  ['sent', 'type', 'food', 'like'],
#  ['done', 'handed', 'celebration', 'full', 'swing', 'yet'],
#  ['got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'person',
#   'definitely',
#   'special',
#   'person',
#   'special',
#   'miss',
#   'keep',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'money', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'last',
#   'night',
#   'get',
#   'ahold',
#   'anybody',
#   'let',
#   'know',
#   'throw'],
#  ['might', 'come', 'tonight', 'class', 'let', 'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'thats',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'love',
#   'life',
#   'love',
#   'people',
#   'life',
#   'world',
#   'call',
#   'friend',
#   'call',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'street',
#   'shall',
#   'update',
#   'tonite',
#   'thing',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'good',
#   'one',
#   'real',
#   'sense'],
#  ['hey', 'told', 'name', 'gautham', 'ah'],
#  ['haf', 'found', 'feel', 'stupid', 'da', 'cam', 'working'],
#  ['oops', 'got', 'bit'],
#  ['much', 'buzy'],
#  ['accidentally', 'deleted', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless', 'situation', 'go', 'gurl', 'would', 'appropriate'],
#  ['hurt',
#   'tease',
#   'make',
#   'cry',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'],
#  ['need', 'coffee', 'run', 'tomo', 'believe', 'time', 'week', 'already'],
#  ['awesome',
#   'remember',
#   'last',
#   'time',
#   'got',
#   'somebody',
#   'high',
#   'first',
#   'time',
#   'diesel'],
#  ['shit',
#   'really',
#   'shocking',
#   'scary',
#   'cant',
#   'imagine',
#   'second',
#   'def',
#   'night',
#   'think',
#   'somewhere',
#   'could',
#   'crash',
#   'night',
#   'save',
#   'taxi'],
#  ['oh', 'way', 'food', 'fridge', 'want', 'go', 'meal', 'tonight'],
#  ['womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'remb', 'think', 'book'],
#  ['jos', 'ask', 'wana', 'meet'],
#  ['lol', 'yes', 'friendship', 'hanging', 'thread', 'cause', 'buy', 'stuff'],
#  ['themob',
#   'check',
#   'newest',
#   'selection',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'sport',
#   'keep',
#   'mobile',
#   'fit',
#   'funky',
#   'text',
#   'wap'],
#  ['garage', 'key', 'bookshelf'],
#  ['today',
#   'accept',
#   'day',
#   'accept',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'week',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['say',
#   'give',
#   'call',
#   'friend',
#   'got',
#   'money',
#   'definitely',
#   'buying',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'day',
#   'normal',
#   'way',
#   'real',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'rest',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'lost'],
#  ['made', 'day', 'great', 'day'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['really', 'dude', 'friend', 'afraid'],
#  ['december',
#   'mobile',
#   'mths',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'babe', 'love', 'ya', 'kiss'],
#  ['hey', 'dont', 'go', 'watch', 'men', 'lunch', 'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['would',
#   'great',
#   'guild',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewhere',
#   'get',
#   'touch',
#   'weekend',
#   'plan',
#   'take',
#   'flight',
#   'good',
#   'week'],
#  ['problem'],
#  ['call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'today', 'class'],
#  ['say',
#   'good',
#   'sign',
#   'well',
#   'know',
#   'track',
#   'record',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'parked'],
#  ['reading', 'text', 'sent', 'meant', 'joke', 'read', 'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'tomo',
#   'return',
#   'immediately',
#   'something'],
#  ['call',
#   'germany',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'prepayment',
#   'direct',
#   'access'],
#  ['chance',
#   'might',
#   'evaporated',
#   'soon',
#   'violated',
#   'privacy',
#   'stealing',
#   'phone',
#   'number',
#   'employer',
#   'paperwork',
#   'cool',
#   'please',
#   'contact',
#   'report',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetime',
#   'send',
#   'go',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'home', 'babe', 'still'],
#  ['cool', 'come', 'havent', 'wined', 'dined'],
#  ['sleeping', 'surfing'],
#  ['sorry', 'call', 'later'],
#  ['calling', 'right', 'call', 'hand', 'phone'],
#  ['ok', 'great', 'thanx', 'lot'],
#  ['take',
#   'post',
#   'come',
#   'must',
#   'text',
#   'happy',
#   'reading',
#   'one',
#   'wiv',
#   'hello',
#   'caroline',
#   'end',
#   'favourite',
#   'bless'],
#  ['hiding', 'stranger'],
#  ['interested', 'like'],
#  ['sister', 'cleared', 'two', 'round', 'birla', 'soft', 'yesterday'],
#  ['gudnite', 'tc', 'practice', 'going'],
#  ['dis',
#   'yijue',
#   'jus',
#   'saw',
#   'ur',
#   'mail',
#   'case',
#   'huiming',
#   'havent',
#   'sent',
#   'num',
#   'dis',
#   'num'],
#  ['one', 'small', 'prestige', 'problem'],
#  ['fancy',
#   'shag',
#   'interested',
#   'sextextuk',
#   'com',
#   'txt',
#   'xxuk',
#   'suzy',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'website'],
#  ['checking', 'really', 'miss', 'seeing', 'jeremiah', 'great', 'month'],
#  ['nah', 'help', 'never', 'iphone'],
#  ['car', 'hour', 'half', 'going', 'apeshit'],
#  ['today',
#   'sorry',
#   'day',
#   'ever',
#   'angry',
#   'ever',
#   'misbehaved',
#   'hurt',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz',
#   'ur',
#   'fault',
#   'basically',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figure',
#   'much',
#   'need',
#   'alcohol',
#   'jay',
#   'trying',
#   'figure',
#   'much',
#   'safely',
#   'spend',
#   'weed'],
#  ['lt', 'gt', 'ish', 'minute', 'minute', 'ago', 'wtf'],
#  ['thank',
#   'calling',
#   'forgot',
#   'say',
#   'happy',
#   'onam',
#   'sirji',
#   'fine',
#   'remembered',
#   'met',
#   'insurance',
#   'person',
#   'meet',
#   'qatar',
#   'insha',
#   'allah',
#   'rakhesh',
#   'ex',
#   'tata',
#   'aig',
#   'joined',
#   'tissco',
#   'tayseer'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'cash',
#   'msg',
#   'cc',
#   'hg',
#   'suite',
#   'land',
#   'row',
#   'hl'],
#  ['actor',
#   'work',
#   'work',
#   'evening',
#   'sleep',
#   'late',
#   'since',
#   'unemployed',
#   'moment',
#   'always',
#   'sleep',
#   'late',
#   'unemployed',
#   'every',
#   'day',
#   'saturday'],
#  ['hello',
#   'got',
#   'st',
#   'andrew',
#   'boy',
#   'long',
#   'way',
#   'cold',
#   'keep',
#   'posted'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku', 'db'],
#  ['oh', 'ok', 'prob'],
#  ['check', 'audrey', 'status', 'right'],
#  ['busy',
#   'trying',
#   'finish',
#   'new',
#   'year',
#   'looking',
#   'forward',
#   'finally',
#   'meeting'],
#  ['good',
#   'afternoon',
#   'sunshine',
#   'dawn',
#   'day',
#   'refreshed',
#   'happy',
#   'alive',
#   'breathe',
#   'air',
#   'smile',
#   'think',
#   'love',
#   'always'],
#  ['well', 'know', 'take', 'care', 'worry'],
#  ['update',
#   'xmas',
#   'offer',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'free',
#   'bluetooth',
#   'double',
#   'min',
#   'txt',
#   'orange',
#   'call',
#   'mobileupd',
#   'call',
#   'optout'],
#  ['discount',
#   'code',
#   'rp',
#   'stop',
#   'message',
#   'reply',
#   'stop',
#   'www',
#   'regalportfolio',
#   'co',
#   'uk',
#   'customer',
#   'service'],
#  ['wat', 'uniform', 'get'],
#  ['cool', 'text', 'ready'],
#  ['hello',
#   'boytoy',
#   'geeee',
#   'miss',
#   'already',
#   'woke',
#   'wish',
#   'bed',
#   'cuddling',
#   'love'],
#  ['spoil', 'bed', 'well'],
#  ['going', 'bath', 'msg', 'next', 'lt', 'gt', 'min'],
#  ['cant',
#   'keep',
#   'talking',
#   'people',
#   'sure',
#   'pay',
#   'agree',
#   'price',
#   'pls',
#   'tell',
#   'want',
#   'really',
#   'buy',
#   'much',
#   'willing',
#   'pay'],
#  ['thanks',
#   'ringtone',
#   'order',
#   'reference',
#   'charged',
#   'gbp',
#   'per',
#   'week',
#   'unsubscribe',
#   'anytime',
#   'calling',
#   'customer',
#   'service'],
#  ['say', 'happen'],
#  ['could', 'seen', 'recognise', 'face'],
#  ['well',
#   'lot',
#   'thing',
#   'happening',
#   'lindsay',
#   'new',
#   'year',
#   'sigh',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'something',
#   'going'],
#  ['keep', 'payasam', 'rinu', 'brings'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'called',
#   'sm',
#   'like',
#   'becaus',
#   'he',
#   'verifying',
#   'project',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistake'],
#  ['guess',
#   'worried',
#   'must',
#   'know',
#   'way',
#   'body',
#   'repair',
#   'quite',
#   'sure',
#   'worry',
#   'take',
#   'slow',
#   'first',
#   'test',
#   'guide',
#   'ovulation',
#   'relax',
#   'nothing',
#   'said',
#   'reason',
#   'worry',
#   'keep',
#   'followin'],
#  ['yeah', 'sure', 'give', 'couple', 'minute', 'track', 'wallet'],
#  ['hey', 'leave', 'big', 'deal', 'take', 'care'],
#  ['hey', 'late', 'ah', 'meet'],
#  ['double',
#   'min',
#   'txts',
#   'month',
#   'free',
#   'bluetooth',
#   'orange',
#   'available',
#   'sony',
#   'nokia',
#   'motorola',
#   'phone',
#   'call',
#   'mobileupd',
#   'call',
#   'optout',
#   'dx'],
#  ['took', 'mr', 'owl', 'lick'],
#  ['customer', 'place', 'call'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   'mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   'update',
#   'stoptxt'],
#  ['yup', 'lunch', 'buffet', 'eat', 'already'],
#  ['huh', 'late', 'fr', 'dinner'],
#  ['hey', 'sat', 'going', 'intro', 'pilate', 'kickboxing'],
#  ['morning', 'ok'],
#  ['yes',
#   'think',
#   'office',
#   'lap',
#   'room',
#   'think',
#   'thats',
#   'last',
#   'day',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', 'ish', 'time', 'going'],
#  ['performance',
#   'award',
#   'calculated',
#   'every',
#   'two',
#   'month',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['actually',
#   'sleeping',
#   'still',
#   'might',
#   'call',
#   'back',
#   'text',
#   'gr',
#   'rock',
#   'si',
#   'send',
#   'text',
#   'wen',
#   'wake'],
#  ['always',
#   'putting',
#   'business',
#   'put',
#   'picture',
#   'as',
#   'facebook',
#   'one',
#   'open',
#   'people',
#   'ever',
#   'met',
#   'would',
#   'think',
#   'picture',
#   'room',
#   'would',
#   'hurt',
#   'make',
#   'feel',
#   'violated'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkum',
#   'sharing',
#   'happy',
#   'news',
#   'grace',
#   'god',
#   'got',
#   'offer',
#   'tayseer',
#   'tissco',
#   'joined',
#   'hope',
#   'fine',
#   'inshah',
#   'allah',
#   'meet',
#   'sometime',
#   'rakhesh',
#   'visitor',
#   'india'],
#  ['hmmm',
#   'want',
#   'change',
#   'field',
#   'quickly',
#   'da',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'network',
#   'administrator'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   'poly',
#   'text',
#   'get',
#   'true',
#   'tone',
#   'help',
#   'st',
#   'free',
#   'tone',
#   'pw',
#   'nd',
#   'txt',
#   'stop'],
#  ['dear', 'chechi', 'talk'],
#  ['hair', 'cream', 'shipped'],
#  ['none', 'happening', 'til', 'get', 'though'],
#  ['yep',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   'lt',
#   'gt',
#   'start',
#   'hour'],
#  ['haha', 'get', 'used', 'driving', 'usf', 'man', 'know', 'lot', 'stoner'],
#  ['well',
#   'slightly',
#   'disastrous',
#   'class',
#   'pm',
#   'fav',
#   'darling',
#   'hope',
#   'day',
#   'ok',
#   'coffee',
#   'wld',
#   'good',
#   'stay',
#   'late',
#   'tomorrow',
#   'time',
#   'place',
#   'always'],
#  ['hello', 'good', 'week', 'fancy', 'drink', 'something', 'later'],
#  ['headin', 'towards', 'busetop'],
#  ['message',
#   'text',
#   'missing',
#   'sender',
#   'name',
#   'missing',
#   'number',
#   'missing',
#   'sent',
#   'date',
#   'missing',
#   'missing',
#   'lot',
#   'thats',
#   'everything',
#   'missing',
#   'sent',
#   'via',
#   'fullonsms',
#   'com'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['okies',
#   'go',
#   'yan',
#   'jiu',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'wendy'],
#  ['dating', 'service', 'cal', 'box', 'sk', 'ch'],
#  ['whatsup', 'dont', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entry',
#   'weekly',
#   'competition',
#   'text',
#   'word',
#   'win',
#   'www',
#   'txttowin',
#   'co',
#   'uk'],
#  ['alright', 'head', 'minute', 'text', 'meet'],
#  ['send',
#   'logo',
#   'ur',
#   'lover',
#   'name',
#   'joined',
#   'heart',
#   'txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'yahoo',
#   'pobox',
#   'wq',
#   'txtno',
#   'ad'],
#  ['yes', 'last', 'week', 'taking', 'live', 'call'],
#  ['someone',
#   'contacted',
#   'dating',
#   'service',
#   'entered',
#   'phone',
#   'fancy',
#   'find',
#   'call',
#   'landline',
#   'pobox',
#   'tf'],
#  ['siva', 'hostel', 'aha'],
#  ['urgent',
#   'mobile',
#   'number',
#   'awarded',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['send',
#   'ur',
#   'friend',
#   'receive',
#   'something',
#   'ur',
#   'voice',
#   'speaking',
#   'expression',
#   'childish',
#   'naughty',
#   'sentiment',
#   'rowdy',
#   'ful',
#   'attitude',
#   'romantic',
#   'shy',
#   'attractive',
#   'funny',
#   'lt',
#   'gt',
#   'irritating',
#   'lt',
#   'gt',
#   'lovable',
#   'reply'],
#  ['ok', 'ok', 'guess'],
#  ['aathi', 'dear'],
#  ['pain', 'urination', 'thing', 'else'],
#  ['esplanade', 'mind', 'giving', 'lift', 'co', 'got', 'car', 'today'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgently',
#   'vry',
#   'urgent',
#   'hv',
#   'shortage',
#   'lt',
#   'gt',
#   'lac',
#   'source',
#   'arng',
#   'dis',
#   'amt',
#   'lt',
#   'gt',
#   'lac',
#   'thats',
#   'prob'],
#  ['home', 'watching', 'tv', 'lor'],
#  ['usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'respond',
#   'yes',
#   'question'],
#  ['congrats',
#   'nokia',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'min',
#   'vary',
#   'mobile',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wc',
#   'xx'],
#  ['booked', 'ticket', 'pongal'],
#  ['available',
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   'amp',
#   'lt',
#   'gt',
#   'th'],
#  ['message',
#   'sent',
#   'askin',
#   'lt',
#   'gt',
#   'dollar',
#   'shoul',
#   'pay',
#   'lt',
#   'gt',
#   'lt',
#   'gt'],
#  ['ask', 'iouri', 'told', 'story', 'like', 'ten', 'time', 'already'],
#  ['long', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'get',
#   'txt',
#   'journey',
#   'hasnt',
#   'gd',
#   'min',
#   'late',
#   'think'],
#  ['like', 'love', 'arrange'],
#  ['yes',
#   'really',
#   'great',
#   'bhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'sachin',
#   'world',
#   'tough',
#   'get'],
#  ['supposed', 'wake', 'gt'],
#  ['oic', 'saw', 'tot', 'din', 'found', 'group', 'liao'],
#  ['sorry', 'call', 'later'],
#  ['hey',
#   'hey',
#   'werethe',
#   'monkeespeople',
#   'say',
#   'monkeyaround',
#   'howdy',
#   'gorgeous',
#   'howu',
#   'doin',
#   'foundurself',
#   'jobyet',
#   'sausage',
#   'love',
#   'jen',
#   'xxx'],
#  ['sorry', 'battery', 'died', 'come', 'getting', 'gram', 'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'hmm'],
#  ['wont', 'get', 'concentration', 'dear', 'know', 'mind', 'everything'],
#  ['lol', 'made', 'plan', 'new', 'year'],
#  ['min', 'later'],
#  ['hank', 'lotsly'],
#  ['thanks', 'hope', 'good', 'day', 'today'],
#  ['detail', 'want', 'transfer', 'acc', 'enough'],
#  ['ok',
#   'tell',
#   'stay',
#   'yeah',
#   'tough',
#   'optimistic',
#   'thing',
#   'improve',
#   'month'],
#  ['loan',
#   'purpose',
#   'homeowner',
#   'tenant',
#   'welcome',
#   'previously',
#   'refused',
#   'still',
#   'help',
#   'call',
#   'free',
#   'text',
#   'back',
#   'help'],
#  ['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffle'],
#  ['look',
#   'amy',
#   'ure',
#   'beautiful',
#   'intelligent',
#   'woman',
#   'like',
#   'lot',
#   'know',
#   'like',
#   'like',
#   'worry'],
#  ['hope',
#   'result',
#   'consistently',
#   'intelligent',
#   'kind',
#   'start',
#   'asking',
#   'practicum',
#   'link',
#   'keep',
#   'ear',
#   'open',
#   'best',
#   'ttyl'],
#  ['call',
#   'cost',
#   'guess',
#   'isnt',
#   'bad',
#   'miss',
#   'ya',
#   'need',
#   'ya',
#   'want',
#   'ya',
#   'love',
#   'ya'],
#  ['going',
#   'thru',
#   'different',
#   'feeling',
#   'wavering',
#   'decision',
#   'coping',
#   'individual',
#   'time',
#   'heal',
#   'everything',
#   'believe'],
#  ['go', 'phone', 'gonna', 'die', 'stay'],
#  ['great', 'never', 'better', 'day', 'give', 'even', 'reason', 'thank', 'god'],
#  ['upgrdcentre',
#   'orange',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'th',
#   'july',
#   'apply',
#   'opt',
#   'available'],
#  ['sorry', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'way', 'railway'],
#  ['great',
#   'princess',
#   'love',
#   'giving',
#   'receiving',
#   'oral',
#   'doggy',
#   'style',
#   'fave',
#   'position',
#   'enjoy',
#   'making',
#   'love',
#   'lt',
#   'gt',
#   'time',
#   'per',
#   'night'],
#  ['put', 'stuff', 'road', 'keep', 'getting', 'slippery'],
#  ['going', 'ride', 'bike'],
#  ['yup', 'need', 'jus', 'wait', 'rain', 'stop'],
#  ['many', 'company', 'tell', 'language'],
#  ['okmail',
#   'dear',
#   'dave',
#   'final',
#   'notice',
#   'collect',
#   'tenerife',
#   'holiday',
#   'cash',
#   'award',
#   'call',
#   'landline',
#   'tc',
#   'sae',
#   'box',
#   'cw',
#   'wx',
#   'ppm'],
#  ['long', 'since', 'screamed', 'princess'],
#  ['nothing',
#   'meant',
#   'money',
#   'enters',
#   'account',
#   'bank',
#   'remove',
#   'flat',
#   'rate',
#   'someone',
#   'transfered',
#   'lt',
#   'gt',
#   'account',
#   'lt',
#   'gt',
#   'dollar',
#   'got',
#   'removed',
#   'bank',
#   'differ',
#   'charge',
#   'also',
#   'differ',
#   'sure',
#   'trust',
#   'ja',
#   'person',
#   'sending',
#   'account',
#   'detail',
#   'co'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'txting',
#   'moan',
#   'nyt',
#   'ec',
#   'msg'],
#  ['nice',
#   'line',
#   'said',
#   'broken',
#   'heart',
#   'plz',
#   'cum',
#   'time',
#   'infront',
#   'wise',
#   'trust',
#   'good'],
#  ['ok', 'gonna', 'head', 'usf', 'like', 'fifteen', 'minute'],
#  ['love', 'aathi', 'love', 'lot'],
#  ['tension', 'ah', 'machi', 'problem'],
#  ['pick', 'another', 'th', 'done'],
#  ['guy', 'getting', 'back', 'said', 'thinking', 'staying', 'mcr'],
#  ['almost', 'see', 'sec'],
#  ['yo', 'carlos', 'friend', 'already', 'asking', 'working', 'weekend'],
#  ['watching', 'tv', 'lor'],
#  ['thank', 'baby', 'cant', 'wait', 'taste', 'real', 'thing'],
#  ['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf'],
#  ['win', 'really', 'side', 'long', 'time'],
#  ['free',
#   'message',
#   'activate',
#   'free',
#   'text',
#   'message',
#   'replying',
#   'message',
#   'word',
#   'free',
#   'term',
#   'condition',
#   'visit',
#   'www',
#   'com'],
#  ['dear', 'reached', 'railway', 'happen'],
#  ['depends',
#   'quality',
#   'want',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'want',
#   'ralphs',
#   'maybe'],
#  ['think', 'fixed', 'send', 'test', 'message'],
#  ['sorry',
#   'man',
#   'account',
#   'dry',
#   'would',
#   'want',
#   'could',
#   'trade',
#   'back',
#   'half',
#   'could',
#   'buy',
#   'shit',
#   'credit',
#   'card'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'meeting', 'call', 'later'],
#  ['class', 'lt', 'gt', 'reunion'],
#  ['free', 'call'],
#  ['got', 'meh'],
#  ['nope', 'think', 'go', 'monday', 'sorry', 'replied', 'late'],
#  ['told', 'accenture', 'confirm', 'true'],
#  ['kate', 'jackson', 'rec', 'center', 'ish', 'right'],
#  ['dear', 'reache', 'room'],
#  ['fighting',
#   'world',
#   'easy',
#   'either',
#   'win',
#   'lose',
#   'bt',
#   'fightng',
#   'close',
#   'dificult',
#   'lose',
#   'lose',
#   'win',
#   'still',
#   'lose'],
#  ['come'],
#  ['check', 'nuerologist'],
#  ['lolnice', 'went', 'fish', 'water'],
#  ['congratulation',
#   'week',
#   'competition',
#   'draw',
#   'prize',
#   'claim',
#   'call',
#   'stop',
#   'sm',
#   'ppm'],
#  ['waiting',
#   'car',
#   'dat',
#   'bored',
#   'wat',
#   'co',
#   'wait',
#   'outside',
#   'got',
#   'nothing',
#   'home',
#   'stuff',
#   'watch',
#   'tv',
#   'wat'],
#  ['maybe', 'westshore', 'hyde', 'park', 'village', 'place', 'near', 'house'],
#  ['know',
#   'anthony',
#   'bringing',
#   'money',
#   'school',
#   'fee',
#   'pay',
#   'rent',
#   'stuff',
#   'like',
#   'thats',
#   'need',
#   'help',
#   'friend',
#   'need'],
#  ['significance'],
#  ['opinion',
#   'jada',
#   'kusruthi',
#   'lovable',
#   'silent',
#   'spl',
#   'character',
#   'matured',
#   'stylish',
#   'simple',
#   'pls',
#   'reply'],
#  ['latest', 'still', 'scrounge', 'ammo', 'want', 'give', 'new', 'ak', 'try'],
#  ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory'],
#  ['lol', 'ok', 'forgiven'],
#  ['jst', 'change', 'tat'],
#  ['guaranteed',
#   'latest',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'prize',
#   'txt',
#   'word',
#   'collect',
#   'ibhltd',
#   'ldnw',
#   'mtmsgrcvd'],
#  ['competition'],
#  ['boltblue',
#   'tone',
#   'reply',
#   'poly',
#   'mono',
#   'eg',
#   'poly',
#   'cha',
#   'cha',
#   'slide',
#   'yeah',
#   'slow',
#   'jamz',
#   'toxic',
#   'come',
#   'stop',
#   'tone',
#   'txt'],
#  ['credit',
#   'topped',
#   'http',
#   'www',
#   'bubbletext',
#   'com',
#   'renewal',
#   'pin',
#   'tgxxrz'],
#  ['way',
#   'transport',
#   'le',
#   'problematic',
#   'sat',
#   'night',
#   'way',
#   'want',
#   'ask',
#   'join',
#   'bday',
#   'feel',
#   'free',
#   'need',
#   'know',
#   'definite',
#   'no',
#   'booking',
#   'fri'],
#  ['usually',
#   'person',
#   'unconscious',
#   'child',
#   'adult',
#   'may',
#   'behave',
#   'abnormally',
#   'call'],
#  ['ebay', 'might', 'le', 'elsewhere'],
#  ['shall', 'come', 'get', 'pickle'],
#  ['gonna', 'go', 'get', 'taco'],
#  ['rude', 'campus'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'nd',
#   'attempt',
#   'contact',
#   'call',
#   'box',
#   'qu'],
#  ['hi', 'ard', 'christmas', 'enjoy', 'merry', 'ma'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['yes', 'pretty', 'lady', 'like', 'single'],
#  ['recieve',
#   'tone',
#   'within',
#   'next',
#   'hr',
#   'term',
#   'condition',
#   'please',
#   'see',
#   'channel',
#   'teletext',
#   'pg'],
#  ['jay', 'say', 'double', 'faggot'],
# ...
#   'ultimatum',
#   'oh',
#   'countin',
#   'aburo',
#   'enjoy',
#   'message',
#   'sent',
#   'day',
#   'ago'],
#  ['surely', 'result', 'offer'],
#  ['good', 'morning', 'dear', 'great', 'amp', 'successful', 'day'],
#  ['want',
#   'anytime',
#   'network',
#   'min',
#   'text',
#   'new',
#   'video',
#   'phone',
#   'five',
#   'pound',
#   'per',
#   'week',
#   'call',
#   'reply',
#   'delivery',
#   'tomorrow'],
#  ['sir',
#   'late',
#   'paying',
#   'rent',
#   'past',
#   'month',
#   'pay',
#   'lt',
#   'gt',
#   'charge',
#   'felt',
#   'would',
#   'inconsiderate',
#   'nag',
#   'something',
#   'give',
#   'great',
#   'cost',
#   'didnt',
#   'speak',
#   'however',
#   'recession',
#   'wont',
#   'able',
#   'pay',
#   'charge',
#   'month',
#   'hence',
#   'askin',
#   'well',
#   'ahead',
#   'month',
#   'end',
#   'please',
#   'help',
#   'thanks'],
#  ['tried',
#   'contact',
#   'offer',
#   'new',
#   'video',
#   'phone',
#   'anytime',
#   'network',
#   'min',
#   'half',
#   'price',
#   'rental',
#   'camcorder',
#   'call',
#   'reply',
#   'delivery',
#   'wed'],
#  ['last',
#   'chance',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'remove',
#   'txt',
#   'stop'],
#  ['luv',
#   'soo',
#   'much',
#   'understand',
#   'special',
#   'ring',
#   'morrow',
#   'luv',
#   'xxx'],
#  ['pls', 'send', 'comprehensive', 'mail', 'paying', 'much'],
#  ['prashanthettan',
#   'mother',
#   'passed',
#   'away',
#   'last',
#   'night',
#   'pray',
#   'family'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'ibiza',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'po',
#   'box',
#   'sk',
#   'wp',
#   'ppm'],
#  ['going'],
#  ['meanwhile',
#   'shit',
#   'suite',
#   'xavier',
#   'decided',
#   'give',
#   'lt',
#   'gt',
#   'second',
#   'warning',
#   'samantha',
#   'coming',
#   'playing',
#   'jay',
#   'guitar',
#   'impress',
#   'shit',
#   'also',
#   'think',
#   'doug',
#   'realizes',
#   'live',
#   'anymore'],
#  ['stomach',
#   'thru',
#   'much',
#   'trauma',
#   'swear',
#   'eat',
#   'better',
#   'lose',
#   'weight'],
#  ['office', 'whats', 'matter', 'msg', 'call', 'break'],
#  ['yeah',
#   'barely',
#   'enough',
#   'room',
#   'two',
#   'many',
#   'fucking',
#   'shoe',
#   'sorry',
#   'man',
#   'see',
#   'later'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['reach', 'orchard', 'already', 'wan', 'go', 'buy', 'ticket', 'first'],
#  ['real', 'baby', 'want', 'bring', 'inner', 'tigress'],
#  ['da', 'run', 'activate', 'full', 'version', 'da'],
#  ['ah',
#   'poor',
#   'baby',
#   'hope',
#   'urfeeling',
#   'bettersn',
#   'luv',
#   'probthat',
#   'overdose',
#   'work',
#   'hey',
#   'go',
#   'careful',
#   'spk',
#   'sn',
#   'lot',
#   'lovejen',
#   'xxx'],
#  ['stop', 'story', 'told', 'returned', 'saying', 'order'],
#  ['talk',
#   'sexy',
#   'make',
#   'new',
#   'friend',
#   'fall',
#   'love',
#   'world',
#   'discreet',
#   'text',
#   'dating',
#   'service',
#   'text',
#   'vip',
#   'see',
#   'could',
#   'meet'],
#  ['going', 'take', 'babe'],
#  ['hai',
#   'ana',
#   'tomarrow',
#   'coming',
#   'morning',
#   'lt',
#   'decimal',
#   'gt',
#   'ill',
#   'sathy',
#   'go',
#   'rto',
#   'office',
#   'reply',
#   'came',
#   'home'],
#  ['spoon', 'okay'],
#  ['say', 'somebody', 'named', 'tampa'],
#  ['work', 'going', 'min'],
#  ['brother', 'genius'],
#  ['sorry',
#   'guess',
#   'whenever',
#   'get',
#   'hold',
#   'connection',
#   'maybe',
#   'hour',
#   'two',
#   'text'],
#  ['find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff'],
#  ['dude', 'ive', 'seeing', 'lotta', 'corvette', 'lately'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'either',
#   'yr',
#   'supply',
#   'cd',
#   'virgin',
#   'record',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   'www',
#   'smsco',
#   'net',
#   'pm',
#   'approx',
#   'min'],
#  ['consider',
#   'wall',
#   'bunker',
#   'shit',
#   'important',
#   'never',
#   'play',
#   'peaceful',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'matter'],
#  ['private',
#   'account',
#   'statement',
#   'xxxxxx',
#   'show',
#   'un',
#   'redeemed',
#   'point',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['hello',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champneys',
#   'put',
#   'need',
#   'address',
#   'dob',
#   'asap',
#   'ta'],
#  ['want',
#   'xmas',
#   'free',
#   'text',
#   'message',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'call',
#   'free',
#   'find'],
#  ['well',
#   'officially',
#   'philosophical',
#   'hole',
#   'wanna',
#   'call',
#   'home',
#   'ready',
#   'saved'],
#  ['going',
#   'good',
#   'problem',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'understand',
#   'american',
#   'customer',
#   'voice'],
#  ['text', 'drop'],
#  ['ugh', 'long', 'day', 'exhausted', 'want', 'cuddle', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day',
#   'otherwise',
#   'miss',
#   'best',
#   'friend',
#   'world',
#   'shakespeare',
#   'shesil',
#   'lt',
#   'gt'],
#  ['shop',
#   'till',
#   'drop',
#   'either',
#   'cash',
#   'travel',
#   'voucher',
#   'call',
#   'ntt',
#   'po',
#   'box',
#   'cr',
#   'bt',
#   'fixedline',
#   'cost',
#   'ppm',
#   'mobile',
#   'vary'],
#  ['castor', 'need', 'see', 'something'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'liverpool',
#   'played',
#   'mid',
#   'week',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call',
#   'stopsms'],
#  ['reminder',
#   'downloaded',
#   'content',
#   'already',
#   'paid',
#   'goto',
#   'http',
#   'doit',
#   'mymoby',
#   'tv',
#   'collect',
#   'content'],
#  ['see',
#   'knew',
#   'giving',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'always',
#   'wanting',
#   'miss',
#   'curfew',
#   'gonna',
#   'gibe',
#   'til',
#   'one',
#   'midnight',
#   'movie',
#   'gonna',
#   'get',
#   'til',
#   'need',
#   'come',
#   'home',
#   'need',
#   'getsleep',
#   'anything',
#   'need',
#   'studdying',
#   'ear',
#   'training'],
#  ['love', 'give', 'massage', 'use', 'lot', 'baby', 'oil', 'fave', 'position'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'know',
#   'change',
#   'permission',
#   'drive',
#   'mac',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like', 'talk', 'pa', 'able', 'dont', 'know'],
#  ['dun', 'cut', 'short', 'leh', 'dun', 'like', 'ah', 'failed', 'quite', 'sad'],
#  ['unbelievable', 'faglord'],
#  ['wife', 'knew', 'time', 'murder', 'exactly'],
#  ['ask', 'princess'],
#  ['great', 'princess', 'thinking'],
#  ['nutter', 'cutter', 'ctter', 'cttergg', 'cttargg', 'ctargg', 'ctagg', 'ie'],
#  ['ok',
#   'noe',
#   'busy',
#   'really',
#   'bored',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choose',
#   'one'],
#  ['class', 'early', 'tomorrow', 'thus', 'trying', 'smoke', 'lt', 'gt'],
#  ['superb',
#   'thought',
#   'grateful',
#   'dont',
#   'everything',
#   'want',
#   'mean',
#   'still',
#   'opportunity',
#   'happier',
#   'tomorrow',
#   'today'],
#  ['hope', 'good', 'week', 'checking'],
#  ['used',
#   'hope',
#   'agent',
#   'drop',
#   'since',
#   'booked',
#   'thing',
#   'year',
#   'whole',
#   'boston',
#   'nyc',
#   'experiment'],
#  ['thursday', 'night', 'yeah', 'sure', 'thing', 'work'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'coming',
#   'due',
#   'several',
#   'outstanding',
#   'invoice',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago'],
#  ['possible', 'teach'],
#  ['wonder', 'phone', 'battery', 'went', 'dead', 'tell', 'love', 'babe'],
#  ['lovely', 'smell', 'bus', 'tobacco'],
#  ['getting', 'worried', 'derek', 'taylor', 'already', 'assumed', 'worst'],
#  ['hey', 'charles', 'sorry', 'late', 'reply'],
#  ['lastest',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap'],
#  ['give', 'plus', 'said', 'grinule', 'greet', 'whenever', 'speak'],
#  ['white', 'fudge', 'oreo', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'min',
#   'cheap',
#   'min',
#   'peak',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['love',
#   'come',
#   'took',
#   'long',
#   'leave',
#   'zaher',
#   'got',
#   'word',
#   'ym',
#   'happy',
#   'see',
#   'sad',
#   'left',
#   'miss'],
#  ['sorry', 'hurt'],
#  ['feel',
#   'nauseous',
#   'pissed',
#   'eat',
#   'sweet',
#   'week',
#   'cause',
#   'today',
#   'planning',
#   'pig',
#   'dieting',
#   'week',
#   'hungry'],
#  ['ok', 'lor', 'early', 'still', 'project', 'meeting'],
#  ['call', 'da', 'waiting', 'call'],
#  ['could', 'ask', 'carlos', 'could', 'get', 'anybody', 'else', 'chip'],
#  ['actually', 'send', 'reminder', 'today', 'wonderful', 'weekend'],
#  ['people',
#   'see',
#   'msg',
#   'think',
#   'iam',
#   'addicted',
#   'msging',
#   'wrong',
#   'bcoz',
#   'know',
#   'iam',
#   'addicted',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'registered',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'yck'],
#  ['dont', 'talk', 'ever', 'ok', 'word'],
#  ['wana', 'see'],
#  ['way', 'school', 'pls', 'send', 'ashley', 'number'],
#  ['shall', 'fine', 'avalarr', 'hollalater'],
#  ['went',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'still',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'old',
#   'website',
#   'blogging',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['diet',
#   'ate',
#   'many',
#   'slice',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'diet'],
#  ['give', 'kvb', 'acc', 'detail'],
#  ['oh', 'come', 'ah'],
#  ['money',
#   'lucky',
#   'winner',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   'million',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'able',
#   'friday',
#   'hope',
#   'find',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   'wa',
#   'enjoy',
#   'wish',
#   'many',
#   'happy',
#   'moment',
#   'fro',
#   'wherever',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'landline',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['dun', 'wear', 'jean', 'lor'],
#  ['since', 'side', 'fever', 'vomitin'],
#  ['college'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'friday',
#   'stuffed',
#   'like',
#   'pig',
#   'yesterday',
#   'feel',
#   'bleh',
#   'least',
#   'writhing',
#   'pain',
#   'kind',
#   'bleh'],
#  ['sell',
#   'ton',
#   'coin',
#   'sell',
#   'coin',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'life',
#   'pocket'],
#  ['theyre', 'lot', 'place', 'hospital', 'medical', 'place', 'safe'],
#  ['getting',
#   'touch',
#   'folk',
#   'waiting',
#   'company',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'enjoy',
#   'community',
#   'sm'],
#  ['also',
#   'sorta',
#   'blown',
#   'couple',
#   'time',
#   'recently',
#   'id',
#   'rather',
#   'text',
#   'blue',
#   'looking',
#   'weed'],
#  ['sent',
#   'score',
#   'sophas',
#   'secondary',
#   'application',
#   'school',
#   'think',
#   'thinking',
#   'applying',
#   'research',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'school',
#   'one',
#   'le',
#   'expensive',
#   'one'],
#  ['cant', 'wait', 'see', 'photo', 'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'go',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'kb',
#   'sat',
#   'already',
#   'lesson',
#   'going',
#   'ah',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodging'],
#  ['chk', 'ur', 'belovd', 'dict'],
#  ['time', 'want', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'gravity',
#   'read',
#   'carefully',
#   'heart',
#   'feel',
#   'light',
#   'someone',
#   'feel',
#   'heavy',
#   'someone',
#   'leaf',
#   'good',
#   'night'],
#  ['also', 'remember', 'get', 'dobby', 'bowl', 'car'],
#  ['filthy', 'story', 'girl', 'waiting'],
#  ['sorry',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'poor',
#   'thing',
#   'one',
#   'night',
#   'tmr',
#   'brand',
#   'new',
#   'room',
#   'sleep'],
#  ['love',
#   'decision',
#   'feeling',
#   'could',
#   'decide',
#   'love',
#   'life',
#   'would',
#   'much',
#   'simpler',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'retired'],
#  ['sort',
#   'code',
#   'acc',
#   'bank',
#   'natwest',
#   'reply',
#   'confirm',
#   'sent',
#   'right',
#   'person'],
#  ['sure', 'take', 'sick', 'time'],
#  ['urgent',
#   'trying',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'eve',
#   'go',
#   'temple',
#   'amp',
#   'church'],
#  ['yo',
#   'chad',
#   'gymnastics',
#   'class',
#   'wanna',
#   'take',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full'],
#  ['much', 'buzy'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', 'lt', 'gt'],
#  ['sure', 'night', 'menu', 'know', 'noon', 'menu'],
#  ['want',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'heart',
#   'thats',
#   'give',
#   'wife',
#   'liking',
#   'see',
#   'one',
#   'give',
#   'dont',
#   'call',
#   'wait',
#   'till',
#   'come'],
#  ['willing', 'go', 'aptitude', 'class'],
#  ['wont', 'trying', 'sort', 'house', 'ok'],
#  ['yar',
#   'lor',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back'],
#  ['yup', 'thk', 'shop', 'close', 'lor'],
#  ['account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'boring',
#   'biatch',
#   'thanx',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesitate',
#   'know',
#   'second',
#   'time',
#   'weakness',
#   'like',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anything',
#   'changed',
#   'day',
#   'sure',
#   'nothing'],
#  ['hey', 'pay', 'salary', 'de', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'alcohol'],
#  ['started', 'searching', 'get', 'job', 'day', 'great', 'potential', 'talent'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', 'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'call',
#   'videochat',
#   'wid',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look', 'fuckin', 'time', 'fuck', 'think'],
#  ['yo', 'guess', 'dropped'],
#  ['carlos', 'say', 'mu', 'lt', 'gt', 'minute'],
#  ['office', 'call', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'already',
#   'know',
#   'think',
#   'fuck',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'ubi',
#   'one',
#   'say',
#   'wan',
#   'call',
#   'tomorrow',
#   'call',
#   'look',
#   'irene',
#   'ere',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh', 'gotta', 'drive', 'back', 'sd', 'la', 'butt', 'sore'],
#  ['th', 'july'],
#  ['hi',
#   'im',
#   'relaxing',
#   'time',
#   'ever',
#   'get',
#   'every',
#   'day',
#   'party',
#   'good',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'ish'],
#  ['wan', 'come', 'come', 'lor', 'din', 'stripe', 'skirt'],
#  ['xmas',
#   'story',
#   'peace',
#   'xmas',
#   'msg',
#   'love',
#   'xmas',
#   'miracle',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['number'],
#  ['change', 'one', 'next', 'escalator'],
#  ['yetunde', 'class', 'run', 'water', 'make', 'ok', 'pls'],
#  ['lot',
#   'happened',
#   'feel',
#   'quiet',
#   'beth',
#   'aunt',
#   'charlie',
#   'working',
#   'lot',
#   'helen',
#   'mo'],
#  ['wait',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'dun',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'pick'],
#  ['aight', 'thanks', 'comin'],
#  ['heard', 'abt', 'tat'],
#  ...]

# %%
# Lets create word2vec from scratch

# %%
import gensim

# %%
## Lets train Word2vec from scratch
model = gensim.models.Word2Vec(words, window = 5, min_count = 2)

# %%
## To Get All the Vocabulary
model.wv.index_to_key
# Out:
# ['call',
#  'get',
#  'ur',
#  'gt',
#  'lt',
#  'go',
#  'ok',
#  'day',
#  'free',
#  'know',
#  'come',
#  'like',
#  'time',
#  'good',
#  'got',
#  'love',
#  'text',
#  'want',
#  'send',
#  'need',
#  'one',
#  'txt',
#  'today',
#  'going',
#  'stop',
#  'home',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'new',
#  'later',
#  'please',
#  'pls',
#  'co',
#  'msg',
#  'min',
#  'make',
#  'night',
#  'dear',
#  'message',
#  'well',
#  'say',
#  'thing',
#  'much',
#  'oh',
#  'hope',
#  'claim',
#  'great',
#  'hey',
#  'give',
#  'number',
#  'happy',
#  'wat',
#  'friend',
#  'work',
#  'way',
#  'yes',
#  'www',
#  'prize',
#  'let',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'cash',
#  'amp',
#  'yeah',
#  'im',
#  'really',
#  'meet',
#  'babe',
#  'find',
#  'miss',
#  'morning',
#  'thanks',
#  'last',
#  'uk',
#  'service',
#  'year',
#  'anything',
#  'care',
#  'would',
#  'com',
#  'also',
#  'lol',
#  'nokia',
#  'feel',
#  'every',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'cant',
#  'wait',
#  'box',
#  'place',
#  'first',
#  'even',
#  'someone',
#  'help',
#  'guy',
#  'nice',
#  'went',
#  'tonight',
#  'next',
#  'wish',
#  'around',
#  'soon',
#  'show',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'late',
#  'many',
#  'per',
#  'chat',
#  'always',
#  'gonna',
#  'ya',
#  'sm',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'dun',
#  'end',
#  'pm',
#  'st',
#  'told',
#  'special',
#  'hello',
#  'person',
#  'waiting',
#  'may',
#  'try',
#  'month',
#  'hour',
#  'fine',
#  'girl',
#  'haha',
#  'people',
#  'heart',
#  'coming',
#  'minute',
#  'best',
#  'th',
#  'getting',
#  'yet',
#  'smile',
#  'done',
#  'thk',
#  'guaranteed',
#  'ppm',
#  'god',
#  'thought',
#  'use',
#  'offer',
#  'holiday',
#  'start',
#  'class',
#  'stuff',
#  'talk',
#  'man',
#  'car',
#  'lunch',
#  'cost',
#  'line',
#  'live',
#  'mean',
#  'bit',
#  'job',
#  'finish',
#  'draw',
#  'problem',
#  'never',
#  'plan',
#  'better',
#  'meeting',
#  'hr',
#  'thats',
#  'trying',
#  'house',
#  'yup',
#  'ill',
#  'cool',
#  'rate',
#  'mind',
#  'long',
#  'dat',
#  'pobox',
#  'account',
#  'ready',
#  'weekend',
#  'chance',
#  'game',
#  'real',
#  'enjoy',
#  'half',
#  'world',
#  'wk',
#  'latest',
#  'bt',
#  'po',
#  'play',
#  'yo',
#  'guess',
#  'sir',
#  'check',
#  'room',
#  'wanna',
#  'sweet',
#  'eat',
#  'camera',
#  'voucher',
#  'nothing',
#  'pic',
#  'look',
#  'receive',
#  'luv',
#  'lar',
#  'boy',
#  'awarded',
#  'another',
#  'shit',
#  'big',
#  'liao',
#  'landline',
#  'dinner',
#  'birthday',
#  'ah',
#  'xxx',
#  'age',
#  'video',
#  'jus',
#  'quite',
#  'ever',
#  'kiss',
#  'might',
#  'watching',
#  'wont',
#  'land',
#  'question',
#  'watch',
#  'tv',
#  'early',
#  'fun',
#  'probably',
#  'orange',
#  'bed',
#  'dream',
#  'aight',
#  'hear',
#  'thanx',
#  'two',
#  'worry',
#  'baby',
#  'speak',
#  'pa',
#  'nd',
#  'point',
#  'called',
#  'nite',
#  'maybe',
#  'apply',
#  'left',
#  'bus',
#  'forgot',
#  'ringtone',
#  'actually',
#  'sat',
#  'network',
#  'princess',
#  'bad',
#  'remember',
#  'den',
#  'shall',
#  'pay',
#  'part',
#  'code',
#  'shopping',
#  'office',
#  'reach',
#  'made',
#  'dunno',
#  'hurt',
#  'easy',
#  'fuck',
#  'leh',
#  'dad',
#  'face',
#  'little',
#  'everything',
#  'anyway',
#  'wife',
#  'true',
#  'xx',
#  'put',
#  'didnt',
#  'evening',
#  'award',
#  'dis',
#  'afternoon',
#  'town',
#  'movie',
#  'school',
#  'gift',
#  'enough',
#  'mate',
#  'sound',
#  'thank',
#  'working',
#  'looking',
#  'selected',
#  'yr',
#  'mail',
#  'entry',
#  'missing',
#  'pound',
#  'collect',
#  'asked',
#  'detail',
#  'tmr',
#  'without',
#  'though',
#  'join',
#  'important',
#  'hav',
#  'wif',
#  'must',
#  'xmas',
#  'wanted',
#  'pain',
#  'sexy',
#  'came',
#  'valid',
#  'okay',
#  'since',
#  'price',
#  'answer',
#  'wot',
#  'abt',
#  'lesson',
#  'able',
#  'wake',
#  'collection',
#  'til',
#  'update',
#  'mob',
#  'run',
#  'book',
#  'missed',
#  'bring',
#  'plus',
#  'stay',
#  'plz',
#  'decimal',
#  'charge',
#  'date',
#  'away',
#  'de',
#  'juz',
#  'wen',
#  'test',
#  'change',
#  'colour',
#  'alright',
#  'hair',
#  'bored',
#  'double',
#  'attempt',
#  'music',
#  'yesterday',
#  'weekly',
#  'else',
#  'till',
#  'shop',
#  'dude',
#  'saw',
#  'havent',
#  'goin',
#  'online',
#  'drink',
#  'optout',
#  'friendship',
#  'oso',
#  'id',
#  'lei',
#  'top',
#  'net',
#  'haf',
#  'trip',
#  'credit',
#  'coz',
#  'making',
#  'food',
#  'player',
#  'either',
#  'sch',
#  'feeling',
#  'family',
#  'national',
#  'ard',
#  'hot',
#  'delivery',
#  'address',
#  'club',
#  'driving',
#  'gr',
#  'smoke',
#  'tried',
#  'http',
#  'lose',
#  'mom',
#  'full',
#  'wid',
#  'sae',
#  'bonus',
#  'head',
#  'post',
#  'second',
#  'walk',
#  'beautiful',
#  'ring',
#  'calling',
#  'busy',
#  'order',
#  'story',
#  'si',
#  'sad',
#  'believe',
#  'brother',
#  'together',
#  'tot',
#  'nt',
#  'mum',
#  'happen',
#  'close',
#  'smiling',
#  'await',
#  'hand',
#  'info',
#  'drive',
#  'old',
#  'leaving',
#  'sleeping',
#  'row',
#  'chikku',
#  'huh',
#  'set',
#  'saying',
#  'poly',
#  'eve',
#  'noe',
#  'email',
#  'private',
#  'started',
#  'finished',
#  'match',
#  'hl',
#  'drop',
#  'okie',
#  'cause',
#  'news',
#  'took',
#  'congrats',
#  'parent',
#  'mths',
#  'suite',
#  'aft',
#  'tomo',
#  'rite',
#  'pub',
#  'thinking',
#  'wil',
#  'awesome',
#  'simple',
#  'forget',
#  'unsubscribe',
#  'auction',
#  'reason',
#  'caller',
#  'content',
#  'available',
#  'neva',
#  'sister',
#  'mine',
#  'anyone',
#  'final',
#  'tho',
#  'gd',
#  'card',
#  'valentine',
#  'angry',
#  'tc',
#  'company',
#  'taking',
#  'break',
#  'statement',
#  'everyone',
#  'touch',
#  'expires',
#  'whats',
#  'open',
#  'type',
#  'search',
#  'treat',
#  'found',
#  'opt',
#  'dating',
#  'sun',
#  'whatever',
#  'knw',
#  'ticket',
#  'alone',
#  'fancy',
#  'choose',
#  'lucky',
#  'bank',
#  'carlos',
#  'gal',
#  'worth',
#  'loving',
#  'hows',
#  'bout',
#  'welcome',
#  'smth',
#  'ha',
#  'saturday',
#  'exam',
#  'uncle',
#  'happened',
#  'party',
#  'identifier',
#  'quiz',
#  'kind',
#  'nyt',
#  'hard',
#  'visit',
#  'college',
#  'wonderful',
#  'sub',
#  'frnd',
#  'fast',
#  'winner',
#  'mobileupd',
#  'ni',
#  'boytoy',
#  'ltd',
#  'decided',
#  'friday',
#  'gbp',
#  'anytime',
#  'prob',
#  'song',
#  'hit',
#  'gone',
#  'far',
#  'congratulation',
#  'secret',
#  'used',
#  'project',
#  'tel',
#  'oredi',
#  'finally',
#  'goodmorning',
#  'mu',
#  'pretty',
#  'sea',
#  'light',
#  'read',
#  'term',
#  'nope',
#  'darlin',
#  'mrng',
#  'outside',
#  'fri',
#  'camcorder',
#  'fucking',
#  'operator',
#  'crazy',
#  'wit',
#  'drug',
#  'chennai',
#  'hold',
#  'wonder',
#  'lovely',
#  'least',
#  'wrong',
#  'support',
#  'blue',
#  'savamob',
#  'earlier',
#  'snow',
#  'wkly',
#  'fone',
#  'frm',
#  'freemsg',
#  'course',
#  'whole',
#  'frnds',
#  'log',
#  'cd',
#  'le',
#  'listen',
#  'meant',
#  'sunday',
#  'hmm',
#  'hungry',
#  'jay',
#  'case',
#  'ten',
#  'unlimited',
#  'fr',
#  'wq',
#  'telling',
#  'seeing',
#  'cum',
#  'john',
#  'rock',
#  'currently',
#  'mr',
#  'father',
#  'india',
#  'understand',
#  'hmmm',
#  'as',
#  'dnt',
#  'gas',
#  'knew',
#  'hee',
#  'motorola',
#  'enter',
#  'invited',
#  'side',
#  'felt',
#  'child',
#  'store',
#  'download',
#  'gn',
#  'moment',
#  'na',
#  'film',
#  'luck',
#  'couple',
#  'mah',
#  'single',
#  'christmas',
#  'sex',
#  'stupid',
#  'etc',
#  'reading',
#  'within',
#  'un',
#  'balance',
#  'almost',
#  'tired',
#  'valued',
#  'lost',
#  'eh',
#  'yar',
#  'computer',
#  'pas',
#  'press',
#  'happiness',
#  'joy',
#  'txts',
#  'move',
#  'area',
#  'cut',
#  'bslvyl',
#  'march',
#  'paper',
#  'die',
#  'sk',
#  'load',
#  'park',
#  'ago',
#  'mayb',
#  'talking',
#  'sell',
#  'gym',
#  'wow',
#  'ac',
#  'difficult',
#  'surprise',
#  'askd',
#  'ugh',
#  'complimentary',
#  'shower',
#  'gotta',
#  'photo',
#  'ipod',
#  'direct',
#  'comp',
#  'red',
#  'return',
#  'via',
#  'darren',
#  'laptop',
#  'reveal',
#  'max',
#  'an',
#  'figure',
#  'bcoz',
#  'ish',
#  'extra',
#  'hospital',
#  'promise',
#  'sending',
#  'heard',
#  'grin',
#  'bill',
#  'information',
#  'swing',
#  'xy',
#  'confirm',
#  'rental',
#  'picking',
#  'kid',
#  'charged',
#  'doin',
#  'ge',
#  'supposed',
#  'redeemed',
#  'seen',
#  'semester',
#  'correct',
#  'eye',
#  'met',
#  'lady',
#  'sort',
#  'fact',
#  'discount',
#  'hg',
#  'eg',
#  'comin',
#  'study',
#  'checking',
#  'fantasy',
#  'ex',
#  'std',
#  'request',
#  'road',
#  'clean',
#  'hmv',
#  'asap',
#  'leaf',
#  'train',
#  'txting',
#  'wana',
#  'whenever',
#  'noon',
#  'reward',
#  'somebody',
#  'lover',
#  'door',
#  'police',
#  'slowly',
#  'rest',
#  'loved',
#  'wap',
#  'link',
#  'pete',
#  'laugh',
#  'lovable',
#  'joke',
#  'blood',
#  'small',
#  'truth',
#  'weed',
#  'slow',
#  'usf',
#  'entered',
#  'kate',
#  'yep',
#  'rent',
#  'crave',
#  'idea',
#  'loan',
#  'safe',
#  'rply',
#  'abiola',
#  'nobody',
#  'monday',
#  'page',
#  'remove',
#  'bath',
#  'cheer',
#  'muz',
#  'save',
#  'asking',
#  'orchard',
#  'dogging',
#  'member',
#  'wine',
#  'write',
#  'sale',
#  'med',
#  'copy',
#  'la',
#  'spend',
#  'callertune',
#  'normal',
#  'convey',
#  'reached',
#  'worried',
#  'merry',
#  'ldn',
#  'voice',
#  'mistake',
#  'bb',
#  'cover',
#  'cheap',
#  'ringtones',
#  'immediately',
#  'hoping',
#  'warm',
#  'getzed',
#  'deep',
#  'il',
#  'poor',
#  'gap',
#  'gave',
#  'em',
#  'different',
#  'usual',
#  'men',
#  'otherwise',
#  'ntt',
#  'cr',
#  'doctor',
#  'indian',
#  'oops',
#  'glad',
#  'ho',
#  'tonite',
#  'energy',
#  'pray',
#  'sony',
#  'somewhere',
#  'del',
#  'booked',
#  'wc',
#  'mm',
#  'fantastic',
#  'custcare',
#  'summer',
#  'opinion',
#  'forever',
#  'teach',
#  'rakhesh',
#  'deal',
#  'representative',
#  'hw',
#  'street',
#  'across',
#  'catch',
#  'king',
#  'bag',
#  'empty',
#  'woke',
#  'near',
#  'england',
#  'situation',
#  'admirer',
#  'short',
#  'cup',
#  'kick',
#  'turn',
#  'water',
#  'bathe',
#  'gettin',
#  'rd',
#  'wishing',
#  'nah',
#  'bluetooth',
#  'self',
#  'flag',
#  'ice',
#  'sunshine',
#  'style',
#  'rose',
#  'unless',
#  'result',
#  'reference',
#  'excellent',
#  'kinda',
#  'specially',
#  'tear',
#  'reaching',
#  'digital',
#  'sick',
#  'none',
#  'decide',
#  'seriously',
#  'sport',
#  'moral',
#  'flight',
#  'rcvd',
#  'bos',
#  'access',
#  'mon',
#  'mo',
#  'round',
#  'urself',
#  'al',
#  'logo',
#  'cake',
#  'iam',
#  'gay',
#  'ending',
#  'meh',
#  'hotel',
#  'brings',
#  'sofa',
#  'buying',
#  'accept',
#  'coffee',
#  'hiya',
#  'password',
#  'silent',
#  'mode',
#  'tht',
#  'wondering',
#  'others',
#  'rain',
#  'add',
#  'user',
#  'especially',
#  'disturb',
#  'trust',
#  'thinkin',
#  'possible',
#  'fall',
#  'bx',
#  'using',
#  'bold',
#  'ip',
#  'dead',
#  'ive',
#  'colleague',
#  'excuse',
#  'lazy',
#  'norm',
#  'ldew',
#  'bid',
#  'starting',
#  'lect',
#  'comuk',
#  'goodnight',
#  'charity',
#  'pc',
#  'studying',
#  'mrt',
#  'forwarded',
#  'seems',
#  'tampa',
#  'stand',
#  'completely',
#  'sitting',
#  'staying',
#  'doesnt',
#  'slave',
#  'finger',
#  'fat',
#  'tuesday',
#  'apartment',
#  'cute',
#  'file',
#  'wednesday',
#  'fill',
#  'list',
#  'issue',
#  'slept',
#  'miracle',
#  'omg',
#  'er',
#  ...]

# %%
model.corpus_count
# Out:
# 5564

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('give', 0.9997060298919678),
#  ('day', 0.9996912479400635),
#  ('much', 0.9996862411499023),
#  ('got', 0.9996612668037415),
#  ('like', 0.9996504783630371),
#  ('night', 0.999642014503479),
#  ('one', 0.9996417164802551),
#  ('going', 0.999639093875885),
#  ('go', 0.9996389746665955),
#  ('get', 0.999637246131897)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'got',
#  'amore',
#  'wat']

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)

    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key], axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X = []
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|          | 0/5564 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5564/5564 [00:00<00:00, 6582.85it/s]

# %%
len(X)
# Out:
# 5564

# %%
##independent Features
X_new = np.array(X)
# Out:
# <ipython-input-79-7db85995600f>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_new = np.array(X)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[1]
# Out:
# array([-0.06000417,  0.17480853,  0.08391489,  0.03008646,  0.03148688,
#        -0.20819724,  0.03857632,  0.35904008, -0.10235371, -0.09693635,
#        -0.10715   , -0.2468966 , -0.02655935,  0.09084232,  0.04891178,
#        -0.18516213,  0.01367468, -0.23612802, -0.01435464, -0.28996032,
#         0.06287982,  0.10808828,  0.06650194, -0.07178103, -0.06503949,
#         0.00754649, -0.13274163, -0.10457119, -0.16845009,  0.02926088,
#         0.18024585,  0.04043346,  0.0943795 , -0.18530585, -0.07126309,
#         0.17923017,  0.02775534, -0.13969597, -0.09765707, -0.25921217,
#         0.03925882, -0.1618865 , -0.06941628,  0.05183046,  0.16971016,
#        -0.09624703, -0.12065281,  0.019271  ,  0.10974934,  0.14762606,
#         0.11005421, -0.19650471, -0.02098496, -0.02440118, -0.09780005,
#         0.13815211,  0.09586562, -0.04781207, -0.19507553,  0.03682303,
#         0.06639253,  0.09631218, -0.0834561 ,  0.00287221, -0.1776041 ,
#         0.11655562,  0.06398328,  0.1431535 , -0.1784984 ,  0.2200836 ,
#        -0.11383235,  0.09626836,  0.19293302, -0.04609929,  0.19929302,
#         0.12149449, -0.00213791, -0.06763919, -0.121268  ,  0.0663768 ,
#        -0.08662686, -0.00734852, -0.161037  ,  0.22742867, -0.02813353,
#         0.00768029, -0.07318993,  0.22859772,  0.23935351,  0.05992271,
#         0.24666497,  0.10352818,  0.0658694 ,  0.09715886,  0.2235939 ,
#         0.19941053,  0.08338567, -0.19774728,  0.05826796, -0.04660381],
#       dtype=float32)

# %%
X_new.shape
# Out:
# (5564,)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y = pd.get_dummies(y['label'])
y = y.iloc[:,0].values

# %%
y.shape
# Out:
# (5564,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df = pd.DataFrame()
for i in range(0,len(X)):
    df = df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# <ipython-input-87-8e8666f5e5b7>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)

# %%
print(df.shape)
df.head()
# Out:
# (5564, 100)
#          0         1         2         3         4         5         6   \
# 0 -0.092711  0.254042  0.128723  0.046018  0.048242 -0.310111  0.054843
# 1 -0.060004  0.174809  0.083915  0.030086  0.031487 -0.208197  0.038576
# 2 -0.092755  0.245701  0.126208  0.053259  0.052615 -0.294078  0.051230
# 3 -0.114003  0.311637  0.160702  0.062310  0.062999 -0.383238  0.066432
# 4 -0.112336  0.303542  0.155837  0.051323  0.054790 -0.365751  0.066892
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.533380 -0.147772 -0.143080  ...  0.368055  0.147404  0.093820  0.147857
# 1  0.359040 -0.102354 -0.096936  ...  0.246665  0.103528  0.065869  0.097159
# 2  0.513839 -0.140817 -0.132156  ...  0.358745  0.144456  0.096623  0.137440
# 3  0.662414 -0.181954 -0.177855  ...  0.452389  0.178611  0.117638  0.180440
# 4  0.633269 -0.176314 -0.167680  ...  0.433445  0.175359  0.115749  0.169817
#
#          94        95        96        97        98        99
# 0  0.330351  0.294077  0.120700 -0.292646  0.087633 -0.077827
# 1  0.223594  0.199411  0.083386 -0.197747  0.058268 -0.046604
# 2  0.322882  0.286104  0.110742 -0.281927  0.085249 -0.074802
# 3  0.404080  0.366662  0.144482 -0.357207  0.106561 -0.095669
# 4  0.393709  0.348526  0.145418 -0.345660  0.104364 -0.092157
#
# [5 rows x 100 columns]

# %%
df['Output'] = y
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.092711  0.254042  0.128723  0.046018  0.048242 -0.310111  0.054843
# 1 -0.060004  0.174809  0.083915  0.030086  0.031487 -0.208197  0.038576
# 2 -0.092755  0.245701  0.126208  0.053259  0.052615 -0.294078  0.051230
# 3 -0.114003  0.311637  0.160702  0.062310  0.062999 -0.383238  0.066432
# 4 -0.112336  0.303542  0.155837  0.051323  0.054790 -0.365751  0.066892
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.533380 -0.147772 -0.143080  ...  0.147404  0.093820  0.147857  0.330351
# 1  0.359040 -0.102354 -0.096936  ...  0.103528  0.065869  0.097159  0.223594
# 2  0.513839 -0.140817 -0.132156  ...  0.144456  0.096623  0.137440  0.322882
# 3  0.662414 -0.181954 -0.177855  ...  0.178611  0.117638  0.180440  0.404080
# 4  0.633269 -0.176314 -0.167680  ...  0.175359  0.115749  0.169817  0.393709
#
#          95        96        97        98        99  Output
# 0  0.294077  0.120700 -0.292646  0.087633 -0.077827       1
# 1  0.199411  0.083386 -0.197747  0.058268 -0.046604       1
# 2  0.286104  0.110742 -0.281927  0.085249 -0.074802       0
# 3  0.366662  0.144482 -0.357207  0.106561 -0.095669       1
# 4  0.348526  0.145418 -0.345660  0.104364 -0.092157       1
#
# [5 rows x 101 columns]

# %%
y = df['Output']

# %%
df.shape
# Out:
# (5564, 101)

# %%
## Independent Feature
X = df.drop(['Output'], axis=1)
X.shape
# Out:
# (5564, 100)

# %%
df.isnull().sum()
# Out:
# 0         23
# 1         23
# 2         23
# 3         23
# 4         23
#           ..
# 96        23
# 97        23
# 98        23
# 99        23
# Output     0
# Length: 101, dtype: int64

# %%
X.isnull().sum()
# Out:
# 0     23
# 1     23
# 2     23
# 3     23
# 4     23
#       ..
# 95    23
# 96    23
# 97    23
# 98    23
# 99    23
# Length: 100, dtype: int64

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#             0         1         2         3         4         5         6   \
# 2777 -0.135224  0.382656  0.196717  0.070709  0.062414 -0.468889  0.082317
# 665  -0.063370  0.163429  0.084648  0.031704  0.031279 -0.197475  0.030290
# 2110 -0.103365  0.286279  0.144542  0.061785  0.060524 -0.341850  0.059221
# 3111 -0.090193  0.239082  0.123560  0.041514  0.041080 -0.287619  0.045747
# 4335 -0.145116  0.359396  0.173936  0.061556  0.076190 -0.421952  0.076487
#
#             7         8         9   ...        90        91        92  \
# 2777  0.805238 -0.230562 -0.214858  ...  0.556438  0.217970  0.141251
# 665   0.345246 -0.095651 -0.091257  ...  0.236726  0.091942  0.060538
# 2110  0.600283 -0.164340 -0.161144  ...  0.414792  0.170296  0.114587
# 3111  0.503722 -0.140941 -0.131172  ...  0.345385  0.140464  0.090264
# 4335  0.741047 -0.199822 -0.195703  ...  0.503308  0.202360  0.147002
#
#             93        94        95        96        97        98        99
# 2777  0.217492  0.494665  0.445437  0.187950 -0.441202  0.136054 -0.121135
# 665   0.100276  0.213571  0.184952  0.076244 -0.183151  0.058973 -0.051769
# 2110  0.172546  0.382992  0.337189  0.122404 -0.326320  0.100975 -0.092938
# 3111  0.135570  0.311200  0.277317  0.115546 -0.272292  0.082719 -0.070147
# 4335  0.191121  0.478662  0.399704  0.179769 -0.397658  0.117525 -0.109039
#
# [5 rows x 100 columns]

# %%
y_train
# Out:
# 2777    1
# 665     1
# 2110    0
# 3111    1
# 4335    1
#        ..
# 1229    1
# 4486    1
# 4968    1
# 2842    1
# 2588    1
# Name: Output, Length: 4451, dtype: uint8

# %%
from sklearn.ensemble import RandomForestClassifier

classifier=RandomForestClassifier()

# %%
X_train.shape,y_train.shape
# Out:
# ((4451, 100), (4451,))

# %%
classifier.fit(X_train,y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))

# %%
print(classification_report(y_test,y_pred))
